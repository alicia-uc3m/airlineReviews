# %% [markdown]
# # Airlines Review

# %% [markdown]
# ---------------------

# %% [markdown]
# ## Phase 3 - LLM Mistral

# %% [markdown]
# ### Environment setup
#
# Setting Up Hugging Face to Use the E: Drive instead of the default C: drive.
# This saves local disk space and helps manage large files better.

# %%
# !pip install transformers datasets peft accelerate bitsandbytes 
import os

# Store all Hugging Face files on the E: drive
os.environ["HF_HOME"] = "E:/huggingface"
os.environ["TRANSFORMERS_CACHE"] = "E:/huggingface/transformers"
os.environ["HF_DATASETS_CACHE"] = "E:/huggingface/datasets"

# %%
import torch
print(torch.cuda.get_device_name(0))
print(f"Total VRAM: {round(torch.cuda.get_device_properties(0).total_memory / 1e9, 2)} GB")
# Out:
# NVIDIA GeForce GTX 1660 Ti
# Total VRAM: 6.44 GB

# %% [markdown]
# ### Load the model
#
# The TinyMistral-248M model is loaded and prepared for efficient fine-tuning:
#
# - First, 4-bit quantization is set up using BitsAndBytesConfig to save GPU memory.
#
# - The tokenizer and base model are loaded from HuggingFace, configured for a 3-class classification task.
#
# - The model is then adapted for 4-bit training with prepare_model_for_kbit_training.
#
# - Finally, LoRA (Low-Rank Adaptation) is applied by injecting lightweight trainable layers into the attention mechanisms (q_proj and v_proj), making the fine-tuning process much faster and lighter.
#
# - The padding token is also corrected after these adjustments to ensure input sequences are properly handled.

# %%
from transformers import BitsAndBytesConfig, AutoTokenizer, AutoModelForSequenceClassification
from peft import prepare_model_for_kbit_training, get_peft_model, LoraConfig, TaskType

# Setup 4-bit Quantization : configure the model to load in 4-bit precision to save memory (important with small VRAM GPUs like 6 GB).
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

#  Load Tokenizer
model_id = "Locutusque/TinyMistral-248M"
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token  #  Add padding

# Base model: Load Pre-trained Mistral Model TinyMistral
model = AutoModelForSequenceClassification.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    num_labels=3, # ready for classification tasks with 3 output classes
    trust_remote_code=True
).to("cuda")

# ✅ Prepare for LoRA after quant: adapt the model for training in 4-bit precision, making it faster and lighter to fine-tune.
model = prepare_model_for_kbit_training(model)

# Apply LoRA Fine-Tuning : configure LoRA (Low-Rank Adaptation) to inject small, efficient trainable adapters into the model’s attention layers.
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.SEQ_CLS
)
model = get_peft_model(model, lora_config)

# Now apply pad_token_id after PEFT
model.config.pad_token_id = tokenizer.pad_token_id

print("Pad token:", tokenizer.pad_token)
print("Pad token ID:", tokenizer.pad_token_id)
# Out:
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Pad token: <|endoftext|>
# Pad token ID: 32001

# %% [markdown]
# ### Load and Preprocess the Dataset

# %% [markdown]
# #### Loading the dataset:

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

# Load the dataset
df = pd.read_csv("./AirlinesReviews/data_phase1.csv", encoding='utf-8', on_bad_lines='skip')
df.head()
# Out:
#                Name Review Date             Airline Verified  \
# 0  Alison Soetantyo  2024-03-01  Singapore Airlines     True
# 1     Robert Watson  2024-02-21  Singapore Airlines     True
# 2             S Han  2024-02-20  Singapore Airlines     True
# 3          D Laynes  2024-02-19  Singapore Airlines     True
# 4         A Othman   2024-02-19  Singapore Airlines     True
#
#   Type of Traveller    Month Flown                         Route  \
# 0      Solo Leisure  December 2023          Jakarta to Singapore
# 1      Solo Leisure  February 2024           Phuket to Singapore
# 2    Family Leisure  February 2024        Siem Reap to Singapore
# 3      Solo Leisure  February 2024  Singapore to London Heathrow
# 4    Family Leisure  February 2024       Singapore to Phnom Penh
#
#             Class  Seat Comfort  Staff Service  Food & Beverages  \
# 0  Business Class             4              4                 4
# 1   Economy Class             5              3                 4
# 2   Economy Class             1              5                 2
# 3   Economy Class             5              5                 5
# 4   Economy Class             5              5                 5
#
#    Inflight Entertainment  Value For Money  Overall Rating Recommended  \
# 0                       4                4               9         yes
# 1                       4                1               3          no
# 2                       1                5              10         yes
# 3                       5                5              10         yes
# 4                       5                5              10         yes
#
#                                               Review Sentiment  Review_Length
# 0  Flight was amazing.   Flight was amazing. The ...  Positive             89
# 1  seats on this aircraft are dreadful .   Bookin...  Negative             49
# 2  Food was plentiful and tasty.   Excellent perf...  Positive             34
# 3  “how much food was available.  Pretty comforta...  Positive            171
# 4  “service was consistently good”.  The service ...  Positive             57

# %% [markdown]
# #### Preprocessing
#
# The dataset is cleaned and prepared by mapping sentiment labels (Positive, Negative, Neutral) to numerical values required for model training.
#
# Only the review text and corresponding label were retained, with the text column renamed to text for compatibility with the tokenizer.
#
# The "Review" column is renamed to "text" to match HuggingFace standards.
#
# The dataset is then split into training, validation, and test sets following an 80%-10%-10% split, ensuring random and reproducible partitions for fine-tuning the Mistral model.
#
# This simplified structure ensures the data is ready for tokenization and fine-tuning with the Mistral model.

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict
import pandas as pd

#  Map sentiment labels to integers
label_map = {'Negative': 0, 'Positive': 1, 'Neutral': 2}
df = df[df['Sentiment'].isin(label_map.keys())]
df['label'] = df['Sentiment'].map(label_map)
df = df[['Review', 'label']].rename(columns={'Review': 'text'})

# === STEP 1: Split original imbalanced data FIRST ===
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'],  # maintain class ratio in test
    random_state=42
)

# === STEP 2: Upsample Neutral class ONLY in training set ===
df_neg = train_df[train_df['label'] == 0]
df_pos = train_df[train_df['label'] == 1]
df_neu = train_df[train_df['label'] == 2]

# Match to largest class
target_size = max(len(df_neg), len(df_pos))
df_neu_upsampled = resample(
    df_neu,
    replace=True,
    n_samples=target_size,
    random_state=42
)

# Combine balanced training set
balanced_train_df = pd.concat([df_neg, df_pos, df_neu_upsampled]).sample(frac=1, random_state=42).reset_index(drop=True)

# === STEP 3: Convert to Hugging Face datasets ===
train_dataset = Dataset.from_pandas(balanced_train_df)
test_dataset = Dataset.from_pandas(test_df)

# === STEP 4: Split train into train/validation (10% val) ===
train_val_split = train_dataset.train_test_split(test_size=0.1111, seed=42)

# === STEP 5: Wrap in DatasetDict ===
dataset = DatasetDict({
    "train": train_val_split["train"],
    "validation": train_val_split["test"],
    "test": test_dataset  # ✅ original imbalanced test
})

# %% [markdown]
# ### Tokenize the Dataset
#
# The dataset is tokenized using the same tokenizer as the Mistral model:
#
# A custom tokenize function is applied to the "text" column, ensuring all sequences are padded or truncated to a maximum length of 512 tokens.
# The dataset is processed in batches for faster tokenization, preparing the text inputs for model training.

# %%
from transformers import AutoTokenizer
def tokenize(example):
    return tokenizer(example["text"], padding="max_length", truncation=True, max_length=512)

tokenized_dataset = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/7866 [00:00<?, ? examples/s]
# Map:   0%|          | 0/984 [00:00<?, ? examples/s]
# Map:   0%|          | 0/810 [00:00<?, ? examples/s]

# %% [markdown]
# ### Hyperparameter Search with Optuna
#
# Hyperparameter optimization is performed using Optuna:
#
# - The model is trained multiple times on the training set, and evaluated on the validation set, with the goal of maximizing the weighted F1-score.
#
# - Optuna explores different learning rates, batch sizes, and numbers of epochs to automatically find the best combination.
#
# - Training is monitored with a custom callback to track progress, and early stopping is used to avoid overfitting.
#
# - To address class imbalance in the dataset, class weights are computed automatically based on the frequency of each emotion label (Positive, Negative, Neutral).
# These weights are applied during training using a custom WeightedTrainer that modifies the loss function.
# This ensures that the model gives more importance to underrepresented classes and does not bias predictions toward majority classes.

# %%
import time
import optuna
import numpy as np
import torch
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight

from transformers import (
    TrainingArguments,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainerCallback,
    EarlyStoppingCallback,
)
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
from transformers import BitsAndBytesConfig
from torch import nn
from transformers import Trainer


#  Class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(df["label"]),
    y=df["label"]
)
class_weights = torch.tensor(class_weights, dtype=torch.float).to("cuda")

#  TRACK TIME PER TRIAL
class TrialProgressCallback(TrainerCallback):
    def __init__(self):
        self.start_time = None

    def on_train_begin(self, args, state, control, **kwargs):
        self.start_time = time.time()
        print(f"\n🚀 Starting trial at {time.strftime('%H:%M:%S')}")

    def on_log(self, args, state, control, logs=None, **kwargs):
        elapsed = time.time() - self.start_time
        print(f"⏱️ Step {state.global_step} - Elapsed: {round(elapsed/60, 2)} min - Logs: {logs}")

#  METRICS
def compute_metrics(pred):
    preds = pred.predictions.argmax(-1)
    return {"f1": f1_score(pred.label_ids, preds, average="weighted")}

#  MODEL INIT (with LoRA)
def model_init():
    base_model = AutoModelForSequenceClassification.from_pretrained(
        model_id,
        quantization_config=bnb_config,
        num_labels=3,
        trust_remote_code=True
    )
    base_model.config.pad_token_id = tokenizer.pad_token_id
    base_model = prepare_model_for_kbit_training(base_model)

    lora_config = LoraConfig(
        r=8,
        lora_alpha=16,
        target_modules=["q_proj", "v_proj"],
        lora_dropout=0.05,
        bias="none",
        task_type=TaskType.SEQ_CLS
    )
    lora_model = get_peft_model(base_model, lora_config)
    return lora_model

#  OPTUNA SEARCH SPACE
def optuna_hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 2e-5, 5e-4, log=True),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [2, 4]),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 2, 3)
    }

#  Custom Trainer with class weights
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits, labels)
        return (loss, outputs) if return_outputs else loss



#  TRAINING ARGS
training_args = TrainingArguments(
    output_dir="./optuna_output",
    eval_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=1,
    metric_for_best_model="f1",
    load_best_model_at_end=True,
    report_to="none",
    logging_dir="./logs",
    logging_strategy="steps",
    logging_steps=100,
    fp16=False
)

#  TRAINER with everything
trainer = WeightedTrainer(
    model_init=model_init,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[
        TrialProgressCallback(),
        EarlyStoppingCallback(early_stopping_patience=2)
    ]
)

#  RUN OPTUNA
start = time.time()

best_trial = trainer.hyperparameter_search(
    direction="maximize",
    hp_space=optuna_hp_space,
    n_trials=3
)

end = time.time()

print("\n✅ Done!")
print(f"⏱️ Optuna tuning done in {round((end - start)/60, 2)} minutes")
print("🏆 Best trial params:", best_trial.hyperparameters)
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_20304\1254717194.py:105: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedTrainer.__init__`. Use `processing_class` instead.
#   trainer = WeightedTrainer(
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# [I 2025-05-27 17:37:55,856] A new study created in memory with name: no-name-0a1b9c76-415a-4624-be96-8b3d56d59d15
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# 🚀 Starting trial at 17:37:56
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='11799' max='11799' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11799/11799 1:44:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.201600</td>
#       <td>0.919895</td>
#       <td>0.760713</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.849500</td>
#       <td>0.905518</td>
#       <td>0.788788</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.870300</td>
#       <td>0.886684</td>
#       <td>0.794574</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 0.9 min - Logs: {'loss': 1.1162, 'grad_norm': 17.354602813720703, 'learning_rate': 7.317371887170678e-05, 'epoch': 0.025425883549453344}
# ⏱️ Step 200 - Elapsed: 1.76 min - Logs: {'loss': 1.086, 'grad_norm': 8.703713417053223, 'learning_rate': 7.254830247109389e-05, 'epoch': 0.05085176709890669}
# ⏱️ Step 300 - Elapsed: 2.61 min - Logs: {'loss': 0.9988, 'grad_norm': 20.841867446899414, 'learning_rate': 7.1922886070481e-05, 'epoch': 0.07627765064836003}
# ⏱️ Step 400 - Elapsed: 3.47 min - Logs: {'loss': 0.9255, 'grad_norm': 24.065855026245117, 'learning_rate': 7.129746966986813e-05, 'epoch': 0.10170353419781338}
# ⏱️ Step 500 - Elapsed: 4.33 min - Logs: {'loss': 0.8775, 'grad_norm': 22.398548126220703, 'learning_rate': 7.067205326925526e-05, 'epoch': 0.12712941774726672}
# ⏱️ Step 600 - Elapsed: 5.19 min - Logs: {'loss': 0.8477, 'grad_norm': 5.368893623352051, 'learning_rate': 7.004663686864238e-05, 'epoch': 0.15255530129672007}
# ⏱️ Step 700 - Elapsed: 6.05 min - Logs: {'loss': 0.8112, 'grad_norm': 18.63935661315918, 'learning_rate': 6.94212204680295e-05, 'epoch': 0.1779811848461734}
# ⏱️ Step 800 - Elapsed: 6.91 min - Logs: {'loss': 0.8268, 'grad_norm': 4.689947605133057, 'learning_rate': 6.879580406741662e-05, 'epoch': 0.20340706839562675}
# ⏱️ Step 900 - Elapsed: 7.79 min - Logs: {'loss': 0.6766, 'grad_norm': 3.527568817138672, 'learning_rate': 6.817038766680375e-05, 'epoch': 0.2288329519450801}
# ⏱️ Step 1000 - Elapsed: 8.66 min - Logs: {'loss': 0.7085, 'grad_norm': 4.450595378875732, 'learning_rate': 6.754497126619088e-05, 'epoch': 0.25425883549453343}
# ⏱️ Step 1100 - Elapsed: 9.52 min - Logs: {'loss': 0.7859, 'grad_norm': 25.515596389770508, 'learning_rate': 6.691955486557799e-05, 'epoch': 0.2796847190439868}
# ⏱️ Step 1200 - Elapsed: 10.38 min - Logs: {'loss': 0.7473, 'grad_norm': 1.376837134361267, 'learning_rate': 6.62941384649651e-05, 'epoch': 0.30511060259344014}
# ⏱️ Step 1300 - Elapsed: 11.24 min - Logs: {'loss': 0.8765, 'grad_norm': 32.72281265258789, 'learning_rate': 6.566872206435223e-05, 'epoch': 0.3305364861428935}
# ⏱️ Step 1400 - Elapsed: 12.11 min - Logs: {'loss': 0.8241, 'grad_norm': 10.06108283996582, 'learning_rate': 6.504330566373935e-05, 'epoch': 0.3559623696923468}
# ⏱️ Step 1500 - Elapsed: 12.98 min - Logs: {'loss': 0.9298, 'grad_norm': 43.74015426635742, 'learning_rate': 6.441788926312648e-05, 'epoch': 0.38138825324180015}
# ⏱️ Step 1600 - Elapsed: 13.84 min - Logs: {'loss': 0.9625, 'grad_norm': 14.597487449645996, 'learning_rate': 6.37924728625136e-05, 'epoch': 0.4068141367912535}
# ⏱️ Step 1700 - Elapsed: 14.71 min - Logs: {'loss': 0.8705, 'grad_norm': 0.23557890951633453, 'learning_rate': 6.316705646190072e-05, 'epoch': 0.43224002034070685}
# ⏱️ Step 1800 - Elapsed: 15.58 min - Logs: {'loss': 0.8228, 'grad_norm': 11.831856727600098, 'learning_rate': 6.254164006128784e-05, 'epoch': 0.4576659038901602}
# ⏱️ Step 1900 - Elapsed: 16.45 min - Logs: {'loss': 0.8046, 'grad_norm': 26.419036865234375, 'learning_rate': 6.191622366067496e-05, 'epoch': 0.4830917874396135}
# ⏱️ Step 2000 - Elapsed: 17.33 min - Logs: {'loss': 0.886, 'grad_norm': 47.585811614990234, 'learning_rate': 6.129080726006208e-05, 'epoch': 0.5085176709890669}
# ⏱️ Step 2100 - Elapsed: 18.22 min - Logs: {'loss': 0.8729, 'grad_norm': 16.765174865722656, 'learning_rate': 6.0665390859449206e-05, 'epoch': 0.5339435545385202}
# ⏱️ Step 2200 - Elapsed: 19.1 min - Logs: {'loss': 0.8201, 'grad_norm': 0.2754681706428528, 'learning_rate': 6.003997445883633e-05, 'epoch': 0.5593694380879736}
# ⏱️ Step 2300 - Elapsed: 19.97 min - Logs: {'loss': 0.9116, 'grad_norm': 39.71775436401367, 'learning_rate': 5.941455805822345e-05, 'epoch': 0.5847953216374269}
# ⏱️ Step 2400 - Elapsed: 20.85 min - Logs: {'loss': 0.6671, 'grad_norm': 9.669568061828613, 'learning_rate': 5.878914165761057e-05, 'epoch': 0.6102212051868803}
# ⏱️ Step 2500 - Elapsed: 21.72 min - Logs: {'loss': 0.9693, 'grad_norm': 2.0955004692077637, 'learning_rate': 5.816372525699769e-05, 'epoch': 0.6356470887363336}
# ⏱️ Step 2600 - Elapsed: 22.53 min - Logs: {'loss': 0.7686, 'grad_norm': 35.99493408203125, 'learning_rate': 5.753830885638481e-05, 'epoch': 0.661072972285787}
# ⏱️ Step 2700 - Elapsed: 23.36 min - Logs: {'loss': 0.7747, 'grad_norm': 6.602383613586426, 'learning_rate': 5.6912892455771935e-05, 'epoch': 0.6864988558352403}
# ⏱️ Step 2800 - Elapsed: 24.18 min - Logs: {'loss': 1.1281, 'grad_norm': 31.288494110107422, 'learning_rate': 5.628747605515906e-05, 'epoch': 0.7119247393846936}
# ⏱️ Step 2900 - Elapsed: 25.01 min - Logs: {'loss': 0.8261, 'grad_norm': 0.5963274836540222, 'learning_rate': 5.566205965454618e-05, 'epoch': 0.737350622934147}
# ⏱️ Step 3000 - Elapsed: 25.83 min - Logs: {'loss': 0.9634, 'grad_norm': 43.583099365234375, 'learning_rate': 5.50366432539333e-05, 'epoch': 0.7627765064836003}
# ⏱️ Step 3100 - Elapsed: 26.65 min - Logs: {'loss': 0.6864, 'grad_norm': 0.649310290813446, 'learning_rate': 5.441122685332042e-05, 'epoch': 0.7882023900330537}
# ⏱️ Step 3200 - Elapsed: 27.45 min - Logs: {'loss': 1.0333, 'grad_norm': 50.989166259765625, 'learning_rate': 5.378581045270754e-05, 'epoch': 0.813628273582507}
# ⏱️ Step 3300 - Elapsed: 28.25 min - Logs: {'loss': 1.1853, 'grad_norm': 37.87845993041992, 'learning_rate': 5.316039405209466e-05, 'epoch': 0.8390541571319603}
# ⏱️ Step 3400 - Elapsed: 29.05 min - Logs: {'loss': 1.056, 'grad_norm': 45.41960525512695, 'learning_rate': 5.2534977651481786e-05, 'epoch': 0.8644800406814137}
# ⏱️ Step 3500 - Elapsed: 29.85 min - Logs: {'loss': 0.7084, 'grad_norm': 2.9322361946105957, 'learning_rate': 5.190956125086891e-05, 'epoch': 0.889905924230867}
# ⏱️ Step 3600 - Elapsed: 30.65 min - Logs: {'loss': 0.9303, 'grad_norm': 29.363178253173828, 'learning_rate': 5.128414485025603e-05, 'epoch': 0.9153318077803204}
# ⏱️ Step 3700 - Elapsed: 31.45 min - Logs: {'loss': 0.8753, 'grad_norm': 8.09614372253418, 'learning_rate': 5.065872844964315e-05, 'epoch': 0.9407576913297737}
# ⏱️ Step 3800 - Elapsed: 32.25 min - Logs: {'loss': 1.0796, 'grad_norm': 7.418673992156982, 'learning_rate': 5.003331204903027e-05, 'epoch': 0.966183574879227}
# ⏱️ Step 3900 - Elapsed: 33.05 min - Logs: {'loss': 1.2016, 'grad_norm': 36.385963439941406, 'learning_rate': 4.9407895648417394e-05, 'epoch': 0.9916094584286804}
# ⏱️ Step 3933 - Elapsed: 34.24 min - Logs: {'eval_loss': 0.9198949337005615, 'eval_f1': 0.7607134058353571, 'eval_runtime': 55.5099, 'eval_samples_per_second': 17.727, 'eval_steps_per_second': 2.216, 'epoch': 1.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 4000 - Elapsed: 34.79 min - Logs: {'loss': 0.7723, 'grad_norm': 0.18539218604564667, 'learning_rate': 4.878247924780452e-05, 'epoch': 1.0170353419781337}
# ⏱️ Step 4100 - Elapsed: 35.6 min - Logs: {'loss': 0.7933, 'grad_norm': 3.7911462783813477, 'learning_rate': 4.815706284719164e-05, 'epoch': 1.0424612255275871}
# ⏱️ Step 4200 - Elapsed: 36.45 min - Logs: {'loss': 0.8687, 'grad_norm': 5.5596160888671875, 'learning_rate': 4.753164644657876e-05, 'epoch': 1.0678871090770405}
# ⏱️ Step 4300 - Elapsed: 37.27 min - Logs: {'loss': 0.8094, 'grad_norm': 0.5400141477584839, 'learning_rate': 4.690623004596588e-05, 'epoch': 1.0933129926264937}
# ⏱️ Step 4400 - Elapsed: 38.1 min - Logs: {'loss': 0.663, 'grad_norm': 2.3294715881347656, 'learning_rate': 4.6280813645353e-05, 'epoch': 1.1187388761759471}
# ⏱️ Step 4500 - Elapsed: 38.93 min - Logs: {'loss': 0.8715, 'grad_norm': 45.824825286865234, 'learning_rate': 4.565539724474012e-05, 'epoch': 1.1441647597254005}
# ⏱️ Step 4600 - Elapsed: 39.74 min - Logs: {'loss': 0.7757, 'grad_norm': 4.027801990509033, 'learning_rate': 4.5029980844127244e-05, 'epoch': 1.1695906432748537}
# ⏱️ Step 4700 - Elapsed: 40.55 min - Logs: {'loss': 1.0152, 'grad_norm': 0.024904560297727585, 'learning_rate': 4.440456444351437e-05, 'epoch': 1.1950165268243071}
# ⏱️ Step 4800 - Elapsed: 41.36 min - Logs: {'loss': 0.943, 'grad_norm': 26.331254959106445, 'learning_rate': 4.377914804290149e-05, 'epoch': 1.2204424103737606}
# ⏱️ Step 4900 - Elapsed: 42.16 min - Logs: {'loss': 0.575, 'grad_norm': 0.14562861621379852, 'learning_rate': 4.315373164228861e-05, 'epoch': 1.2458682939232137}
# ⏱️ Step 5000 - Elapsed: 42.98 min - Logs: {'loss': 0.8033, 'grad_norm': 0.1324266791343689, 'learning_rate': 4.252831524167573e-05, 'epoch': 1.2712941774726672}
# ⏱️ Step 5100 - Elapsed: 43.8 min - Logs: {'loss': 0.9132, 'grad_norm': 32.75612258911133, 'learning_rate': 4.190289884106285e-05, 'epoch': 1.2967200610221206}
# ⏱️ Step 5200 - Elapsed: 44.62 min - Logs: {'loss': 0.7935, 'grad_norm': 0.14082297682762146, 'learning_rate': 4.127748244044997e-05, 'epoch': 1.3221459445715738}
# ⏱️ Step 5300 - Elapsed: 45.43 min - Logs: {'loss': 0.6586, 'grad_norm': 2.2974772453308105, 'learning_rate': 4.0652066039837095e-05, 'epoch': 1.3475718281210272}
# ⏱️ Step 5400 - Elapsed: 46.28 min - Logs: {'loss': 0.9108, 'grad_norm': 0.10513130575418472, 'learning_rate': 4.002664963922422e-05, 'epoch': 1.3729977116704806}
# ⏱️ Step 5500 - Elapsed: 47.1 min - Logs: {'loss': 0.7833, 'grad_norm': 0.52470862865448, 'learning_rate': 3.940123323861134e-05, 'epoch': 1.398423595219934}
# ⏱️ Step 5600 - Elapsed: 47.92 min - Logs: {'loss': 0.9791, 'grad_norm': 0.15534695982933044, 'learning_rate': 3.877581683799846e-05, 'epoch': 1.4238494787693872}
# ⏱️ Step 5700 - Elapsed: 48.74 min - Logs: {'loss': 0.7401, 'grad_norm': 45.75162887573242, 'learning_rate': 3.815040043738558e-05, 'epoch': 1.4492753623188406}
# ⏱️ Step 5800 - Elapsed: 49.56 min - Logs: {'loss': 0.8189, 'grad_norm': 8.128294944763184, 'learning_rate': 3.75249840367727e-05, 'epoch': 1.474701245868294}
# ⏱️ Step 5900 - Elapsed: 50.37 min - Logs: {'loss': 0.6455, 'grad_norm': 0.6489090919494629, 'learning_rate': 3.6899567636159824e-05, 'epoch': 1.5001271294177472}
# ⏱️ Step 6000 - Elapsed: 51.19 min - Logs: {'loss': 0.8115, 'grad_norm': 0.37554654479026794, 'learning_rate': 3.6274151235546945e-05, 'epoch': 1.5255530129672006}
# ⏱️ Step 6100 - Elapsed: 52.01 min - Logs: {'loss': 0.821, 'grad_norm': 4.8690996170043945, 'learning_rate': 3.564873483493407e-05, 'epoch': 1.550978896516654}
# ⏱️ Step 6200 - Elapsed: 52.9 min - Logs: {'loss': 0.699, 'grad_norm': 43.334171295166016, 'learning_rate': 3.502331843432119e-05, 'epoch': 1.5764047800661074}
# ⏱️ Step 6300 - Elapsed: 53.77 min - Logs: {'loss': 1.2098, 'grad_norm': 36.63450622558594, 'learning_rate': 3.439790203370831e-05, 'epoch': 1.6018306636155606}
# ⏱️ Step 6400 - Elapsed: 54.65 min - Logs: {'loss': 0.946, 'grad_norm': 46.60725402832031, 'learning_rate': 3.377248563309544e-05, 'epoch': 1.627256547165014}
# ⏱️ Step 6500 - Elapsed: 55.6 min - Logs: {'loss': 0.7026, 'grad_norm': 9.288594245910645, 'learning_rate': 3.314706923248255e-05, 'epoch': 1.6526824307144672}
# ⏱️ Step 6600 - Elapsed: 56.51 min - Logs: {'loss': 0.8723, 'grad_norm': 40.20780944824219, 'learning_rate': 3.2521652831869675e-05, 'epoch': 1.6781083142639206}
# ⏱️ Step 6700 - Elapsed: 57.39 min - Logs: {'loss': 0.6965, 'grad_norm': 39.46937942504883, 'learning_rate': 3.18962364312568e-05, 'epoch': 1.703534197813374}
# ⏱️ Step 6800 - Elapsed: 58.26 min - Logs: {'loss': 0.777, 'grad_norm': 1.5008982419967651, 'learning_rate': 3.127082003064392e-05, 'epoch': 1.7289600813628274}
# ⏱️ Step 6900 - Elapsed: 59.14 min - Logs: {'loss': 0.7544, 'grad_norm': 34.609764099121094, 'learning_rate': 3.064540363003104e-05, 'epoch': 1.7543859649122808}
# ⏱️ Step 7000 - Elapsed: 60.02 min - Logs: {'loss': 0.8701, 'grad_norm': 9.28216552734375, 'learning_rate': 3.0019987229418164e-05, 'epoch': 1.779811848461734}
# ⏱️ Step 7100 - Elapsed: 60.88 min - Logs: {'loss': 0.5536, 'grad_norm': 5.139802932739258, 'learning_rate': 2.9394570828805285e-05, 'epoch': 1.8052377320111874}
# ⏱️ Step 7200 - Elapsed: 61.74 min - Logs: {'loss': 1.1068, 'grad_norm': 4.096571445465088, 'learning_rate': 2.8769154428192404e-05, 'epoch': 1.8306636155606406}
# ⏱️ Step 7300 - Elapsed: 62.6 min - Logs: {'loss': 0.7132, 'grad_norm': 1.1630443334579468, 'learning_rate': 2.814373802757953e-05, 'epoch': 1.856089499110094}
# ⏱️ Step 7400 - Elapsed: 63.46 min - Logs: {'loss': 0.6193, 'grad_norm': 0.013596073724329472, 'learning_rate': 2.751832162696665e-05, 'epoch': 1.8815153826595474}
# ⏱️ Step 7500 - Elapsed: 64.32 min - Logs: {'loss': 0.8114, 'grad_norm': 4.0317254066467285, 'learning_rate': 2.689290522635377e-05, 'epoch': 1.9069412662090008}
# ⏱️ Step 7600 - Elapsed: 65.18 min - Logs: {'loss': 0.9498, 'grad_norm': 30.57390785217285, 'learning_rate': 2.6267488825740893e-05, 'epoch': 1.9323671497584543}
# ⏱️ Step 7700 - Elapsed: 66.04 min - Logs: {'loss': 0.6338, 'grad_norm': 28.311702728271484, 'learning_rate': 2.5642072425128015e-05, 'epoch': 1.9577930333079074}
# ⏱️ Step 7800 - Elapsed: 66.9 min - Logs: {'loss': 0.8495, 'grad_norm': 0.24411725997924805, 'learning_rate': 2.5016656024515136e-05, 'epoch': 1.9832189168573608}
# ⏱️ Step 7866 - Elapsed: 68.46 min - Logs: {'eval_loss': 0.9055179357528687, 'eval_f1': 0.7887879331843662, 'eval_runtime': 59.622, 'eval_samples_per_second': 16.504, 'eval_steps_per_second': 2.063, 'epoch': 2.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 7900 - Elapsed: 68.78 min - Logs: {'loss': 0.6472, 'grad_norm': 0.6215434670448303, 'learning_rate': 2.439123962390226e-05, 'epoch': 2.008644800406814}
# ⏱️ Step 8000 - Elapsed: 69.69 min - Logs: {'loss': 0.7789, 'grad_norm': 8.242461204528809, 'learning_rate': 2.376582322328938e-05, 'epoch': 2.0340706839562674}
# ⏱️ Step 8100 - Elapsed: 70.61 min - Logs: {'loss': 0.7151, 'grad_norm': 0.0590372197329998, 'learning_rate': 2.31404068226765e-05, 'epoch': 2.059496567505721}
# ⏱️ Step 8200 - Elapsed: 71.52 min - Logs: {'loss': 0.8961, 'grad_norm': 0.09146124869585037, 'learning_rate': 2.2514990422063622e-05, 'epoch': 2.0849224510551743}
# ⏱️ Step 8300 - Elapsed: 72.4 min - Logs: {'loss': 0.8963, 'grad_norm': 0.017997564747929573, 'learning_rate': 2.1889574021450744e-05, 'epoch': 2.1103483346046277}
# ⏱️ Step 8400 - Elapsed: 73.29 min - Logs: {'loss': 0.6633, 'grad_norm': 20.651395797729492, 'learning_rate': 2.1264157620837865e-05, 'epoch': 2.135774218154081}
# ⏱️ Step 8500 - Elapsed: 74.19 min - Logs: {'loss': 0.9056, 'grad_norm': 0.10066866874694824, 'learning_rate': 2.0638741220224987e-05, 'epoch': 2.161200101703534}
# ⏱️ Step 8600 - Elapsed: 75.07 min - Logs: {'loss': 0.7234, 'grad_norm': 0.04174630343914032, 'learning_rate': 2.001332481961211e-05, 'epoch': 2.1866259852529875}
# ⏱️ Step 8700 - Elapsed: 75.95 min - Logs: {'loss': 0.6263, 'grad_norm': 23.05203628540039, 'learning_rate': 1.938790841899923e-05, 'epoch': 2.212051868802441}
# ⏱️ Step 8800 - Elapsed: 76.83 min - Logs: {'loss': 0.6312, 'grad_norm': 7.34372091293335, 'learning_rate': 1.876249201838635e-05, 'epoch': 2.2374777523518943}
# ⏱️ Step 8900 - Elapsed: 77.71 min - Logs: {'loss': 0.5884, 'grad_norm': 5.659656524658203, 'learning_rate': 1.8137075617773473e-05, 'epoch': 2.2629036359013477}
# ⏱️ Step 9000 - Elapsed: 78.59 min - Logs: {'loss': 0.5086, 'grad_norm': 1.5958327054977417, 'learning_rate': 1.7511659217160594e-05, 'epoch': 2.288329519450801}
# ⏱️ Step 9100 - Elapsed: 79.48 min - Logs: {'loss': 0.7594, 'grad_norm': 1.6621613502502441, 'learning_rate': 1.688624281654772e-05, 'epoch': 2.313755403000254}
# ⏱️ Step 9200 - Elapsed: 80.36 min - Logs: {'loss': 0.9315, 'grad_norm': 0.10027022659778595, 'learning_rate': 1.6260826415934837e-05, 'epoch': 2.3391812865497075}
# ⏱️ Step 9300 - Elapsed: 81.24 min - Logs: {'loss': 0.9268, 'grad_norm': 43.331966400146484, 'learning_rate': 1.563541001532196e-05, 'epoch': 2.364607170099161}
# ⏱️ Step 9400 - Elapsed: 82.12 min - Logs: {'loss': 0.5855, 'grad_norm': 6.0106048583984375, 'learning_rate': 1.5009993614709082e-05, 'epoch': 2.3900330536486143}
# ⏱️ Step 9500 - Elapsed: 83.0 min - Logs: {'loss': 0.5325, 'grad_norm': 13.262109756469727, 'learning_rate': 1.4384577214096202e-05, 'epoch': 2.4154589371980677}
# ⏱️ Step 9600 - Elapsed: 83.88 min - Logs: {'loss': 0.7167, 'grad_norm': 6.816530704498291, 'learning_rate': 1.3759160813483325e-05, 'epoch': 2.440884820747521}
# ⏱️ Step 9700 - Elapsed: 84.76 min - Logs: {'loss': 0.817, 'grad_norm': 22.064905166625977, 'learning_rate': 1.3133744412870447e-05, 'epoch': 2.4663107042969745}
# ⏱️ Step 9800 - Elapsed: 85.64 min - Logs: {'loss': 0.7661, 'grad_norm': 0.29569366574287415, 'learning_rate': 1.2508328012257568e-05, 'epoch': 2.4917365878464275}
# ⏱️ Step 9900 - Elapsed: 86.52 min - Logs: {'loss': 0.8181, 'grad_norm': 44.18590545654297, 'learning_rate': 1.188291161164469e-05, 'epoch': 2.517162471395881}
# ⏱️ Step 10000 - Elapsed: 87.4 min - Logs: {'loss': 0.7695, 'grad_norm': 0.010629518888890743, 'learning_rate': 1.1257495211031811e-05, 'epoch': 2.5425883549453343}
# ⏱️ Step 10100 - Elapsed: 88.28 min - Logs: {'loss': 0.7163, 'grad_norm': 4.621624946594238, 'learning_rate': 1.0632078810418933e-05, 'epoch': 2.5680142384947877}
# ⏱️ Step 10200 - Elapsed: 89.16 min - Logs: {'loss': 0.7273, 'grad_norm': 17.82164192199707, 'learning_rate': 1.0006662409806056e-05, 'epoch': 2.593440122044241}
# ⏱️ Step 10300 - Elapsed: 90.03 min - Logs: {'loss': 0.825, 'grad_norm': 23.453176498413086, 'learning_rate': 9.381246009193176e-06, 'epoch': 2.6188660055936945}
# ⏱️ Step 10400 - Elapsed: 90.89 min - Logs: {'loss': 0.9061, 'grad_norm': 42.32600021362305, 'learning_rate': 8.755829608580297e-06, 'epoch': 2.6442918891431475}
# ⏱️ Step 10500 - Elapsed: 91.75 min - Logs: {'loss': 0.7236, 'grad_norm': 0.8171287775039673, 'learning_rate': 8.130413207967419e-06, 'epoch': 2.669717772692601}
# ⏱️ Step 10600 - Elapsed: 92.61 min - Logs: {'loss': 0.7931, 'grad_norm': 0.43283453583717346, 'learning_rate': 7.504996807354541e-06, 'epoch': 2.6951436562420543}
# ⏱️ Step 10700 - Elapsed: 93.48 min - Logs: {'loss': 0.6755, 'grad_norm': 57.838253021240234, 'learning_rate': 6.8795804067416625e-06, 'epoch': 2.7205695397915077}
# ⏱️ Step 10800 - Elapsed: 94.35 min - Logs: {'loss': 0.5499, 'grad_norm': 2.537374973297119, 'learning_rate': 6.254164006128784e-06, 'epoch': 2.745995423340961}
# ⏱️ Step 10900 - Elapsed: 95.24 min - Logs: {'loss': 0.6185, 'grad_norm': 55.58661651611328, 'learning_rate': 5.6287476055159055e-06, 'epoch': 2.7714213068904145}
# ⏱️ Step 11000 - Elapsed: 96.1 min - Logs: {'loss': 0.7288, 'grad_norm': 0.32705676555633545, 'learning_rate': 5.003331204903028e-06, 'epoch': 2.796847190439868}
# ⏱️ Step 11100 - Elapsed: 96.96 min - Logs: {'loss': 0.854, 'grad_norm': 43.683719635009766, 'learning_rate': 4.3779148042901486e-06, 'epoch': 2.8222730739893214}
# ⏱️ Step 11200 - Elapsed: 97.83 min - Logs: {'loss': 0.7683, 'grad_norm': 1.026253581047058, 'learning_rate': 3.7524984036772705e-06, 'epoch': 2.8476989575387743}
# ⏱️ Step 11300 - Elapsed: 98.71 min - Logs: {'loss': 0.7444, 'grad_norm': 11.280986785888672, 'learning_rate': 3.127082003064392e-06, 'epoch': 2.8731248410882277}
# ⏱️ Step 11400 - Elapsed: 99.66 min - Logs: {'loss': 0.6241, 'grad_norm': 43.70551300048828, 'learning_rate': 2.501665602451514e-06, 'epoch': 2.898550724637681}
# ⏱️ Step 11500 - Elapsed: 100.67 min - Logs: {'loss': 0.731, 'grad_norm': 46.73643493652344, 'learning_rate': 1.8762492018386352e-06, 'epoch': 2.9239766081871346}
# ⏱️ Step 11600 - Elapsed: 101.58 min - Logs: {'loss': 0.7588, 'grad_norm': 5.636312007904053, 'learning_rate': 1.250832801225757e-06, 'epoch': 2.949402491736588}
# ⏱️ Step 11700 - Elapsed: 102.5 min - Logs: {'loss': 0.8703, 'grad_norm': 0.013782504945993423, 'learning_rate': 6.254164006128785e-07, 'epoch': 2.974828375286041}
# ⏱️ Step 11799 - Elapsed: 104.48 min - Logs: {'eval_loss': 0.8866839408874512, 'eval_f1': 0.7945739907621111, 'eval_runtime': 64.1678, 'eval_samples_per_second': 15.335, 'eval_steps_per_second': 1.917, 'epoch': 3.0}
# ⏱️ Step 11799 - Elapsed: 104.49 min - Logs: {'train_runtime': 6269.5194, 'train_samples_per_second': 3.764, 'train_steps_per_second': 1.882, 'total_flos': 1.3251981172801536e+16, 'train_loss': 0.8123736128947302, 'epoch': 3.0}
# [I 2025-05-27 19:22:27,431] Trial 0 finished with value: 0.7945739907621111 and parameters: {'learning_rate': 7.379288110831352e-05, 'per_device_train_batch_size': 2, 'num_train_epochs': 3}. Best is trial 0 with value: 0.7945739907621111.
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting trial at 19:22:28
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='5901' max='5901' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5901/5901 2:06:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.711300</td>
#       <td>0.642841</td>
#       <td>0.776022</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.549000</td>
#       <td>0.689544</td>
#       <td>0.793612</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.577600</td>
#       <td>0.655661</td>
#       <td>0.810064</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 2.12 min - Logs: {'loss': 1.0923, 'grad_norm': 9.305536270141602, 'learning_rate': 0.0001193612523482202, 'epoch': 0.05083884087442806}
# ⏱️ Step 200 - Elapsed: 4.23 min - Logs: {'loss': 0.9474, 'grad_norm': 15.959235191345215, 'learning_rate': 0.00011730400911574485, 'epoch': 0.10167768174885612}
# ⏱️ Step 300 - Elapsed: 6.33 min - Logs: {'loss': 0.827, 'grad_norm': 7.3491740226745605, 'learning_rate': 0.0001152467658832695, 'epoch': 0.1525165226232842}
# ⏱️ Step 400 - Elapsed: 8.43 min - Logs: {'loss': 0.7962, 'grad_norm': 17.798126220703125, 'learning_rate': 0.00011318952265079413, 'epoch': 0.20335536349771224}
# ⏱️ Step 500 - Elapsed: 10.52 min - Logs: {'loss': 0.647, 'grad_norm': 8.831413269042969, 'learning_rate': 0.00011113227941831877, 'epoch': 0.2541942043721403}
# ⏱️ Step 600 - Elapsed: 12.62 min - Logs: {'loss': 0.655, 'grad_norm': 8.403214454650879, 'learning_rate': 0.0001090750361858434, 'epoch': 0.3050330452465684}
# ⏱️ Step 700 - Elapsed: 14.55 min - Logs: {'loss': 0.6459, 'grad_norm': 10.589390754699707, 'learning_rate': 0.00010701779295336807, 'epoch': 0.35587188612099646}
# ⏱️ Step 800 - Elapsed: 16.49 min - Logs: {'loss': 0.7228, 'grad_norm': 10.457388877868652, 'learning_rate': 0.0001049605497208927, 'epoch': 0.4067107269954245}
# ⏱️ Step 900 - Elapsed: 18.41 min - Logs: {'loss': 0.6525, 'grad_norm': 5.649357795715332, 'learning_rate': 0.00010290330648841734, 'epoch': 0.45754956786985257}
# ⏱️ Step 1000 - Elapsed: 20.36 min - Logs: {'loss': 0.6394, 'grad_norm': 35.971229553222656, 'learning_rate': 0.00010084606325594199, 'epoch': 0.5083884087442806}
# ⏱️ Step 1100 - Elapsed: 22.31 min - Logs: {'loss': 0.6397, 'grad_norm': 13.217903137207031, 'learning_rate': 9.878882002346664e-05, 'epoch': 0.5592272496187087}
# ⏱️ Step 1200 - Elapsed: 24.24 min - Logs: {'loss': 0.6004, 'grad_norm': 9.251569747924805, 'learning_rate': 9.673157679099128e-05, 'epoch': 0.6100660904931368}
# ⏱️ Step 1300 - Elapsed: 26.14 min - Logs: {'loss': 0.6474, 'grad_norm': 14.565070152282715, 'learning_rate': 9.467433355851591e-05, 'epoch': 0.6609049313675648}
# ⏱️ Step 1400 - Elapsed: 28.03 min - Logs: {'loss': 0.7023, 'grad_norm': 21.59947395324707, 'learning_rate': 9.261709032604056e-05, 'epoch': 0.7117437722419929}
# ⏱️ Step 1500 - Elapsed: 30.0 min - Logs: {'loss': 0.6439, 'grad_norm': 19.310136795043945, 'learning_rate': 9.05598470935652e-05, 'epoch': 0.762582613116421}
# ⏱️ Step 1600 - Elapsed: 31.95 min - Logs: {'loss': 0.6825, 'grad_norm': 21.496585845947266, 'learning_rate': 8.850260386108985e-05, 'epoch': 0.813421453990849}
# ⏱️ Step 1700 - Elapsed: 33.88 min - Logs: {'loss': 0.7661, 'grad_norm': 14.712076187133789, 'learning_rate': 8.64453606286145e-05, 'epoch': 0.8642602948652771}
# ⏱️ Step 1800 - Elapsed: 35.79 min - Logs: {'loss': 0.6169, 'grad_norm': 12.065500259399414, 'learning_rate': 8.438811739613913e-05, 'epoch': 0.9150991357397051}
# ⏱️ Step 1900 - Elapsed: 37.73 min - Logs: {'loss': 0.7113, 'grad_norm': 22.62161636352539, 'learning_rate': 8.233087416366377e-05, 'epoch': 0.9659379766141332}
# ⏱️ Step 1967 - Elapsed: 39.99 min - Logs: {'eval_loss': 0.642841100692749, 'eval_f1': 0.7760220804217258, 'eval_runtime': 58.4969, 'eval_samples_per_second': 16.821, 'eval_steps_per_second': 2.103, 'epoch': 1.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 2000 - Elapsed: 40.63 min - Logs: {'loss': 0.7023, 'grad_norm': 12.974275588989258, 'learning_rate': 8.027363093118843e-05, 'epoch': 1.0167768174885612}
# ⏱️ Step 2100 - Elapsed: 42.61 min - Logs: {'loss': 0.5801, 'grad_norm': 7.5302815437316895, 'learning_rate': 7.821638769871307e-05, 'epoch': 1.0676156583629894}
# ⏱️ Step 2200 - Elapsed: 44.55 min - Logs: {'loss': 0.5468, 'grad_norm': 12.412310600280762, 'learning_rate': 7.61591444662377e-05, 'epoch': 1.1184544992374175}
# ⏱️ Step 2300 - Elapsed: 46.48 min - Logs: {'loss': 0.5928, 'grad_norm': 1.8654537200927734, 'learning_rate': 7.410190123376234e-05, 'epoch': 1.1692933401118455}
# ⏱️ Step 2400 - Elapsed: 48.42 min - Logs: {'loss': 0.7188, 'grad_norm': 25.297657012939453, 'learning_rate': 7.204465800128699e-05, 'epoch': 1.2201321809862735}
# ⏱️ Step 2500 - Elapsed: 50.38 min - Logs: {'loss': 0.5163, 'grad_norm': 7.9633564949035645, 'learning_rate': 6.998741476881164e-05, 'epoch': 1.2709710218607015}
# ⏱️ Step 2600 - Elapsed: 52.35 min - Logs: {'loss': 0.6573, 'grad_norm': 5.542609214782715, 'learning_rate': 6.793017153633628e-05, 'epoch': 1.3218098627351296}
# ⏱️ Step 2700 - Elapsed: 54.29 min - Logs: {'loss': 0.5942, 'grad_norm': 3.2683072090148926, 'learning_rate': 6.587292830386093e-05, 'epoch': 1.3726487036095576}
# ⏱️ Step 2800 - Elapsed: 56.26 min - Logs: {'loss': 0.6007, 'grad_norm': 27.274778366088867, 'learning_rate': 6.381568507138556e-05, 'epoch': 1.4234875444839858}
# ⏱️ Step 2900 - Elapsed: 58.25 min - Logs: {'loss': 0.5611, 'grad_norm': 8.872784614562988, 'learning_rate': 6.175844183891021e-05, 'epoch': 1.4743263853584139}
# ⏱️ Step 3000 - Elapsed: 60.16 min - Logs: {'loss': 0.5198, 'grad_norm': 4.561563968658447, 'learning_rate': 5.9701198606434856e-05, 'epoch': 1.525165226232842}
# ⏱️ Step 3100 - Elapsed: 62.08 min - Logs: {'loss': 0.5371, 'grad_norm': 13.970340728759766, 'learning_rate': 5.76439553739595e-05, 'epoch': 1.57600406710727}
# ⏱️ Step 3200 - Elapsed: 64.01 min - Logs: {'loss': 0.7538, 'grad_norm': 9.48994255065918, 'learning_rate': 5.558671214148414e-05, 'epoch': 1.6268429079816982}
# ⏱️ Step 3300 - Elapsed: 65.95 min - Logs: {'loss': 0.5904, 'grad_norm': 5.804681777954102, 'learning_rate': 5.3529468909008785e-05, 'epoch': 1.6776817488561262}
# ⏱️ Step 3400 - Elapsed: 67.92 min - Logs: {'loss': 0.5277, 'grad_norm': 9.639471054077148, 'learning_rate': 5.147222567653343e-05, 'epoch': 1.7285205897305542}
# ⏱️ Step 3500 - Elapsed: 69.88 min - Logs: {'loss': 0.5966, 'grad_norm': 19.52075958251953, 'learning_rate': 4.941498244405807e-05, 'epoch': 1.7793594306049823}
# ⏱️ Step 3600 - Elapsed: 71.88 min - Logs: {'loss': 0.6163, 'grad_norm': 12.534201622009277, 'learning_rate': 4.7357739211582714e-05, 'epoch': 1.8301982714794103}
# ⏱️ Step 3700 - Elapsed: 73.85 min - Logs: {'loss': 0.484, 'grad_norm': 12.580465316772461, 'learning_rate': 4.5300495979107356e-05, 'epoch': 1.8810371123538383}
# ⏱️ Step 3800 - Elapsed: 75.85 min - Logs: {'loss': 0.6325, 'grad_norm': 1.9143569469451904, 'learning_rate': 4.3243252746632e-05, 'epoch': 1.9318759532282663}
# ⏱️ Step 3900 - Elapsed: 78.28 min - Logs: {'loss': 0.549, 'grad_norm': 1.9393160343170166, 'learning_rate': 4.118600951415664e-05, 'epoch': 1.9827147941026944}
# ⏱️ Step 3934 - Elapsed: 80.37 min - Logs: {'eval_loss': 0.6895437836647034, 'eval_f1': 0.7936115710682058, 'eval_runtime': 79.243, 'eval_samples_per_second': 12.417, 'eval_steps_per_second': 1.552, 'epoch': 2.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 4000 - Elapsed: 82.11 min - Logs: {'loss': 0.5176, 'grad_norm': 12.795262336730957, 'learning_rate': 3.9128766281681285e-05, 'epoch': 2.0335536349771224}
# ⏱️ Step 4100 - Elapsed: 84.65 min - Logs: {'loss': 0.5786, 'grad_norm': 12.042179107666016, 'learning_rate': 3.7071523049205935e-05, 'epoch': 2.0843924758515504}
# ⏱️ Step 4200 - Elapsed: 87.04 min - Logs: {'loss': 0.5963, 'grad_norm': 0.4469873905181885, 'learning_rate': 3.501427981673057e-05, 'epoch': 2.135231316725979}
# ⏱️ Step 4300 - Elapsed: 89.44 min - Logs: {'loss': 0.5854, 'grad_norm': 1.744767427444458, 'learning_rate': 3.2957036584255214e-05, 'epoch': 2.186070157600407}
# ⏱️ Step 4400 - Elapsed: 91.86 min - Logs: {'loss': 0.4504, 'grad_norm': 4.811198711395264, 'learning_rate': 3.089979335177986e-05, 'epoch': 2.236908998474835}
# ⏱️ Step 4500 - Elapsed: 94.29 min - Logs: {'loss': 0.4352, 'grad_norm': 2.6062073707580566, 'learning_rate': 2.8842550119304503e-05, 'epoch': 2.287747839349263}
# ⏱️ Step 4600 - Elapsed: 96.71 min - Logs: {'loss': 0.6027, 'grad_norm': 6.987044811248779, 'learning_rate': 2.6785306886829146e-05, 'epoch': 2.338586680223691}
# ⏱️ Step 4700 - Elapsed: 99.15 min - Logs: {'loss': 0.5283, 'grad_norm': 8.739696502685547, 'learning_rate': 2.472806365435379e-05, 'epoch': 2.389425521098119}
# ⏱️ Step 4800 - Elapsed: 101.58 min - Logs: {'loss': 0.4471, 'grad_norm': 0.45104271173477173, 'learning_rate': 2.2670820421878432e-05, 'epoch': 2.440264361972547}
# ⏱️ Step 4900 - Elapsed: 104.0 min - Logs: {'loss': 0.5657, 'grad_norm': 16.788135528564453, 'learning_rate': 2.0613577189403075e-05, 'epoch': 2.491103202846975}
# ⏱️ Step 5000 - Elapsed: 106.43 min - Logs: {'loss': 0.5649, 'grad_norm': 15.465618133544922, 'learning_rate': 1.8556333956927718e-05, 'epoch': 2.541942043721403}
# ⏱️ Step 5100 - Elapsed: 108.85 min - Logs: {'loss': 0.5304, 'grad_norm': 3.4127602577209473, 'learning_rate': 1.649909072445236e-05, 'epoch': 2.592780884595831}
# ⏱️ Step 5200 - Elapsed: 111.26 min - Logs: {'loss': 0.6073, 'grad_norm': 22.613346099853516, 'learning_rate': 1.4441847491977005e-05, 'epoch': 2.643619725470259}
# ⏱️ Step 5300 - Elapsed: 113.59 min - Logs: {'loss': 0.5934, 'grad_norm': 20.001392364501953, 'learning_rate': 1.2384604259501648e-05, 'epoch': 2.6944585663446876}
# ⏱️ Step 5400 - Elapsed: 115.64 min - Logs: {'loss': 0.4538, 'grad_norm': 24.565807342529297, 'learning_rate': 1.032736102702629e-05, 'epoch': 2.745297407219115}
# ⏱️ Step 5500 - Elapsed: 117.64 min - Logs: {'loss': 0.4847, 'grad_norm': 10.936314582824707, 'learning_rate': 8.270117794550934e-06, 'epoch': 2.7961362480935437}
# ⏱️ Step 5600 - Elapsed: 119.63 min - Logs: {'loss': 0.5995, 'grad_norm': 7.273772239685059, 'learning_rate': 6.2128745620755775e-06, 'epoch': 2.8469750889679717}
# ⏱️ Step 5700 - Elapsed: 121.6 min - Logs: {'loss': 0.4753, 'grad_norm': 6.382391929626465, 'learning_rate': 4.155631329600221e-06, 'epoch': 2.8978139298423997}
# ⏱️ Step 5800 - Elapsed: 123.61 min - Logs: {'loss': 0.5486, 'grad_norm': 10.11191177368164, 'learning_rate': 2.0983880971248637e-06, 'epoch': 2.9486527707168277}
# ⏱️ Step 5900 - Elapsed: 125.61 min - Logs: {'loss': 0.5776, 'grad_norm': 8.9564847946167, 'learning_rate': 4.114486464950713e-08, 'epoch': 2.9994916115912558}
# ⏱️ Step 5901 - Elapsed: 126.63 min - Logs: {'eval_loss': 0.6556612849235535, 'eval_f1': 0.8100640712161892, 'eval_runtime': 61.0793, 'eval_samples_per_second': 16.11, 'eval_steps_per_second': 2.014, 'epoch': 3.0}
# ⏱️ Step 5901 - Elapsed: 126.64 min - Logs: {'train_runtime': 7598.4078, 'train_samples_per_second': 3.106, 'train_steps_per_second': 0.777, 'total_flos': 1.3251981172801536e+16, 'train_loss': 0.6144392884948298, 'epoch': 3.0}
# [I 2025-05-27 21:29:07,828] Trial 1 finished with value: 0.8100640712161892 and parameters: {'learning_rate': 0.0001213979231483708, 'per_device_train_batch_size': 4, 'num_train_epochs': 3}. Best is trial 1 with value: 0.8100640712161892.
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting trial at 21:29:08
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='11799' max='11799' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11799/11799 1:45:03, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.071600</td>
#       <td>0.851844</td>
#       <td>0.780047</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.681900</td>
#       <td>0.884037</td>
#       <td>0.814688</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.649500</td>
#       <td>0.830791</td>
#       <td>0.828066</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 0.87 min - Logs: {'loss': 1.1012, 'grad_norm': 17.019407272338867, 'learning_rate': 0.0001750014406743405, 'epoch': 0.025425883549453344}
# ⏱️ Step 200 - Elapsed: 1.73 min - Logs: {'loss': 1.008, 'grad_norm': 5.946736812591553, 'learning_rate': 0.0001735057018651581, 'epoch': 0.05085176709890669}
# ⏱️ Step 300 - Elapsed: 2.6 min - Logs: {'loss': 0.7708, 'grad_norm': 7.7479119300842285, 'learning_rate': 0.0001720099630559757, 'epoch': 0.07627765064836003}
# ⏱️ Step 400 - Elapsed: 3.47 min - Logs: {'loss': 0.7755, 'grad_norm': 7.070446968078613, 'learning_rate': 0.0001705142242467933, 'epoch': 0.10170353419781338}
# ⏱️ Step 500 - Elapsed: 4.34 min - Logs: {'loss': 0.9009, 'grad_norm': 19.29374122619629, 'learning_rate': 0.0001690184854376109, 'epoch': 0.12712941774726672}
# ⏱️ Step 600 - Elapsed: 5.2 min - Logs: {'loss': 0.9166, 'grad_norm': 2.347876787185669, 'learning_rate': 0.00016752274662842852, 'epoch': 0.15255530129672007}
# ⏱️ Step 700 - Elapsed: 6.07 min - Logs: {'loss': 0.8658, 'grad_norm': 5.513867378234863, 'learning_rate': 0.0001660270078192461, 'epoch': 0.1779811848461734}
# ⏱️ Step 800 - Elapsed: 6.94 min - Logs: {'loss': 1.0661, 'grad_norm': 2.184574842453003, 'learning_rate': 0.00016453126901006372, 'epoch': 0.20340706839562675}
# ⏱️ Step 900 - Elapsed: 7.81 min - Logs: {'loss': 0.7979, 'grad_norm': 1.348209023475647, 'learning_rate': 0.00016303553020088131, 'epoch': 0.2288329519450801}
# ⏱️ Step 1000 - Elapsed: 8.67 min - Logs: {'loss': 0.8959, 'grad_norm': 0.7859931588172913, 'learning_rate': 0.00016153979139169893, 'epoch': 0.25425883549453343}
# ⏱️ Step 1100 - Elapsed: 9.54 min - Logs: {'loss': 0.8938, 'grad_norm': 25.828296661376953, 'learning_rate': 0.00016004405258251652, 'epoch': 0.2796847190439868}
# ⏱️ Step 1200 - Elapsed: 10.41 min - Logs: {'loss': 0.9004, 'grad_norm': 1.275246024131775, 'learning_rate': 0.0001585483137733341, 'epoch': 0.30511060259344014}
# ⏱️ Step 1300 - Elapsed: 11.28 min - Logs: {'loss': 1.0554, 'grad_norm': 3.289416551589966, 'learning_rate': 0.00015705257496415173, 'epoch': 0.3305364861428935}
# ⏱️ Step 1400 - Elapsed: 12.14 min - Logs: {'loss': 0.8696, 'grad_norm': 5.33390474319458, 'learning_rate': 0.00015555683615496932, 'epoch': 0.3559623696923468}
# ⏱️ Step 1500 - Elapsed: 13.01 min - Logs: {'loss': 0.9517, 'grad_norm': 34.571678161621094, 'learning_rate': 0.00015406109734578694, 'epoch': 0.38138825324180015}
# ⏱️ Step 1600 - Elapsed: 13.88 min - Logs: {'loss': 1.056, 'grad_norm': 6.9106011390686035, 'learning_rate': 0.00015256535853660455, 'epoch': 0.4068141367912535}
# ⏱️ Step 1700 - Elapsed: 14.74 min - Logs: {'loss': 0.8306, 'grad_norm': 0.4257824718952179, 'learning_rate': 0.00015106961972742214, 'epoch': 0.43224002034070685}
# ⏱️ Step 1800 - Elapsed: 15.61 min - Logs: {'loss': 0.8637, 'grad_norm': 6.421780109405518, 'learning_rate': 0.00014957388091823973, 'epoch': 0.4576659038901602}
# ⏱️ Step 1900 - Elapsed: 16.48 min - Logs: {'loss': 0.8047, 'grad_norm': 28.876455307006836, 'learning_rate': 0.00014807814210905735, 'epoch': 0.4830917874396135}
# ⏱️ Step 2000 - Elapsed: 17.35 min - Logs: {'loss': 0.8678, 'grad_norm': 45.817283630371094, 'learning_rate': 0.00014658240329987494, 'epoch': 0.5085176709890669}
# ⏱️ Step 2100 - Elapsed: 18.21 min - Logs: {'loss': 0.8684, 'grad_norm': 13.390715599060059, 'learning_rate': 0.00014508666449069256, 'epoch': 0.5339435545385202}
# ⏱️ Step 2200 - Elapsed: 19.08 min - Logs: {'loss': 0.7799, 'grad_norm': 0.24871230125427246, 'learning_rate': 0.00014359092568151015, 'epoch': 0.5593694380879736}
# ⏱️ Step 2300 - Elapsed: 19.95 min - Logs: {'loss': 0.9736, 'grad_norm': 38.743289947509766, 'learning_rate': 0.00014209518687232777, 'epoch': 0.5847953216374269}
# ⏱️ Step 2400 - Elapsed: 20.81 min - Logs: {'loss': 0.6946, 'grad_norm': 6.244152545928955, 'learning_rate': 0.00014059944806314536, 'epoch': 0.6102212051868803}
# ⏱️ Step 2500 - Elapsed: 21.68 min - Logs: {'loss': 0.989, 'grad_norm': 1.8375755548477173, 'learning_rate': 0.00013910370925396297, 'epoch': 0.6356470887363336}
# ⏱️ Step 2600 - Elapsed: 22.55 min - Logs: {'loss': 0.7523, 'grad_norm': 32.135597229003906, 'learning_rate': 0.00013760797044478056, 'epoch': 0.661072972285787}
# ⏱️ Step 2700 - Elapsed: 23.42 min - Logs: {'loss': 0.7665, 'grad_norm': 1.461113691329956, 'learning_rate': 0.00013611223163559815, 'epoch': 0.6864988558352403}
# ⏱️ Step 2800 - Elapsed: 24.28 min - Logs: {'loss': 1.0953, 'grad_norm': 16.364253997802734, 'learning_rate': 0.00013461649282641577, 'epoch': 0.7119247393846936}
# ⏱️ Step 2900 - Elapsed: 25.15 min - Logs: {'loss': 0.8384, 'grad_norm': 0.6518356800079346, 'learning_rate': 0.00013312075401723336, 'epoch': 0.737350622934147}
# ⏱️ Step 3000 - Elapsed: 26.02 min - Logs: {'loss': 0.8872, 'grad_norm': 45.77400207519531, 'learning_rate': 0.00013162501520805098, 'epoch': 0.7627765064836003}
# ⏱️ Step 3100 - Elapsed: 26.88 min - Logs: {'loss': 0.6943, 'grad_norm': 0.28160807490348816, 'learning_rate': 0.00013012927639886857, 'epoch': 0.7882023900330537}
# ⏱️ Step 3200 - Elapsed: 27.75 min - Logs: {'loss': 1.0282, 'grad_norm': 31.998233795166016, 'learning_rate': 0.00012863353758968619, 'epoch': 0.813628273582507}
# ⏱️ Step 3300 - Elapsed: 28.62 min - Logs: {'loss': 1.1259, 'grad_norm': 36.756412506103516, 'learning_rate': 0.00012713779878050378, 'epoch': 0.8390541571319603}
# ⏱️ Step 3400 - Elapsed: 29.49 min - Logs: {'loss': 0.9575, 'grad_norm': 34.57349395751953, 'learning_rate': 0.00012564205997132137, 'epoch': 0.8644800406814137}
# ⏱️ Step 3500 - Elapsed: 30.36 min - Logs: {'loss': 0.6939, 'grad_norm': 2.4642179012298584, 'learning_rate': 0.00012414632116213898, 'epoch': 0.889905924230867}
# ⏱️ Step 3600 - Elapsed: 31.22 min - Logs: {'loss': 0.9865, 'grad_norm': 20.281164169311523, 'learning_rate': 0.00012265058235295657, 'epoch': 0.9153318077803204}
# ⏱️ Step 3700 - Elapsed: 32.09 min - Logs: {'loss': 0.8305, 'grad_norm': 2.6497316360473633, 'learning_rate': 0.00012115484354377419, 'epoch': 0.9407576913297737}
# ⏱️ Step 3800 - Elapsed: 32.95 min - Logs: {'loss': 0.9806, 'grad_norm': 10.07744026184082, 'learning_rate': 0.0001196591047345918, 'epoch': 0.966183574879227}
# ⏱️ Step 3900 - Elapsed: 33.82 min - Logs: {'loss': 1.0716, 'grad_norm': 28.581918716430664, 'learning_rate': 0.0001181633659254094, 'epoch': 0.9916094584286804}
# ⏱️ Step 3933 - Elapsed: 35.11 min - Logs: {'eval_loss': 0.8518438339233398, 'eval_f1': 0.7800470547886863, 'eval_runtime': 60.2623, 'eval_samples_per_second': 16.329, 'eval_steps_per_second': 2.041, 'epoch': 1.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 4000 - Elapsed: 35.7 min - Logs: {'loss': 0.6478, 'grad_norm': 0.14166556298732758, 'learning_rate': 0.000116667627116227, 'epoch': 1.0170353419781337}
# ⏱️ Step 4100 - Elapsed: 36.56 min - Logs: {'loss': 0.6961, 'grad_norm': 1.086085557937622, 'learning_rate': 0.00011517188830704459, 'epoch': 1.0424612255275871}
# ⏱️ Step 4200 - Elapsed: 37.43 min - Logs: {'loss': 0.8022, 'grad_norm': 9.959230422973633, 'learning_rate': 0.0001136761494978622, 'epoch': 1.0678871090770405}
# ⏱️ Step 4300 - Elapsed: 38.3 min - Logs: {'loss': 0.749, 'grad_norm': 0.3586465120315552, 'learning_rate': 0.0001121804106886798, 'epoch': 1.0933129926264937}
# ⏱️ Step 4400 - Elapsed: 39.16 min - Logs: {'loss': 0.5676, 'grad_norm': 0.9739956855773926, 'learning_rate': 0.0001106846718794974, 'epoch': 1.1187388761759471}
# ⏱️ Step 4500 - Elapsed: 40.03 min - Logs: {'loss': 0.7901, 'grad_norm': 40.108070373535156, 'learning_rate': 0.00010918893307031501, 'epoch': 1.1441647597254005}
# ⏱️ Step 4600 - Elapsed: 40.9 min - Logs: {'loss': 0.7651, 'grad_norm': 3.2281758785247803, 'learning_rate': 0.00010769319426113263, 'epoch': 1.1695906432748537}
# ⏱️ Step 4700 - Elapsed: 41.76 min - Logs: {'loss': 0.8774, 'grad_norm': 0.011764980852603912, 'learning_rate': 0.00010619745545195023, 'epoch': 1.1950165268243071}
# ⏱️ Step 4800 - Elapsed: 42.63 min - Logs: {'loss': 0.7887, 'grad_norm': 12.62559700012207, 'learning_rate': 0.0001047017166427678, 'epoch': 1.2204424103737606}
# ⏱️ Step 4900 - Elapsed: 43.5 min - Logs: {'loss': 0.4991, 'grad_norm': 0.21154846251010895, 'learning_rate': 0.00010320597783358541, 'epoch': 1.2458682939232137}
# ⏱️ Step 5000 - Elapsed: 44.36 min - Logs: {'loss': 0.7941, 'grad_norm': 0.05305880680680275, 'learning_rate': 0.00010171023902440303, 'epoch': 1.2712941774726672}
# ⏱️ Step 5100 - Elapsed: 45.23 min - Logs: {'loss': 0.8103, 'grad_norm': 30.295368194580078, 'learning_rate': 0.00010021450021522063, 'epoch': 1.2967200610221206}
# ⏱️ Step 5200 - Elapsed: 46.1 min - Logs: {'loss': 0.7512, 'grad_norm': 0.04439208284020424, 'learning_rate': 9.871876140603823e-05, 'epoch': 1.3221459445715738}
# ⏱️ Step 5300 - Elapsed: 46.96 min - Logs: {'loss': 0.6058, 'grad_norm': 0.5746722221374512, 'learning_rate': 9.722302259685584e-05, 'epoch': 1.3475718281210272}
# ⏱️ Step 5400 - Elapsed: 47.83 min - Logs: {'loss': 0.8007, 'grad_norm': 0.1527341604232788, 'learning_rate': 9.572728378767344e-05, 'epoch': 1.3729977116704806}
# ⏱️ Step 5500 - Elapsed: 48.72 min - Logs: {'loss': 0.6741, 'grad_norm': 0.8171118497848511, 'learning_rate': 9.423154497849103e-05, 'epoch': 1.398423595219934}
# ⏱️ Step 5600 - Elapsed: 49.58 min - Logs: {'loss': 0.7484, 'grad_norm': 0.05150248855352402, 'learning_rate': 9.273580616930864e-05, 'epoch': 1.4238494787693872}
# ⏱️ Step 5700 - Elapsed: 50.45 min - Logs: {'loss': 0.7072, 'grad_norm': 43.636173248291016, 'learning_rate': 9.124006736012624e-05, 'epoch': 1.4492753623188406}
# ⏱️ Step 5800 - Elapsed: 51.32 min - Logs: {'loss': 0.6143, 'grad_norm': 15.736513137817383, 'learning_rate': 8.974432855094384e-05, 'epoch': 1.474701245868294}
# ⏱️ Step 5900 - Elapsed: 52.18 min - Logs: {'loss': 0.4758, 'grad_norm': 0.016871504485607147, 'learning_rate': 8.824858974176145e-05, 'epoch': 1.5001271294177472}
# ⏱️ Step 6000 - Elapsed: 53.05 min - Logs: {'loss': 0.7302, 'grad_norm': 0.035930294543504715, 'learning_rate': 8.675285093257905e-05, 'epoch': 1.5255530129672006}
# ⏱️ Step 6100 - Elapsed: 53.92 min - Logs: {'loss': 0.7945, 'grad_norm': 1.2986403703689575, 'learning_rate': 8.525711212339665e-05, 'epoch': 1.550978896516654}
# ⏱️ Step 6200 - Elapsed: 54.78 min - Logs: {'loss': 0.5456, 'grad_norm': 33.8859977722168, 'learning_rate': 8.376137331421426e-05, 'epoch': 1.5764047800661074}
# ⏱️ Step 6300 - Elapsed: 55.65 min - Logs: {'loss': 1.1091, 'grad_norm': 37.74885177612305, 'learning_rate': 8.226563450503186e-05, 'epoch': 1.6018306636155606}
# ⏱️ Step 6400 - Elapsed: 56.52 min - Logs: {'loss': 0.7847, 'grad_norm': 44.230045318603516, 'learning_rate': 8.076989569584947e-05, 'epoch': 1.627256547165014}
# ⏱️ Step 6500 - Elapsed: 57.38 min - Logs: {'loss': 0.6462, 'grad_norm': 0.394633412361145, 'learning_rate': 7.927415688666706e-05, 'epoch': 1.6526824307144672}
# ⏱️ Step 6600 - Elapsed: 58.25 min - Logs: {'loss': 0.7846, 'grad_norm': 36.95487594604492, 'learning_rate': 7.777841807748466e-05, 'epoch': 1.6781083142639206}
# ⏱️ Step 6700 - Elapsed: 59.12 min - Logs: {'loss': 0.5803, 'grad_norm': 36.00318908691406, 'learning_rate': 7.628267926830228e-05, 'epoch': 1.703534197813374}
# ⏱️ Step 6800 - Elapsed: 59.98 min - Logs: {'loss': 0.6728, 'grad_norm': 0.5915830135345459, 'learning_rate': 7.478694045911987e-05, 'epoch': 1.7289600813628274}
# ⏱️ Step 6900 - Elapsed: 60.85 min - Logs: {'loss': 0.7286, 'grad_norm': 39.004573822021484, 'learning_rate': 7.329120164993747e-05, 'epoch': 1.7543859649122808}
# ⏱️ Step 7000 - Elapsed: 61.72 min - Logs: {'loss': 0.7867, 'grad_norm': 23.106775283813477, 'learning_rate': 7.179546284075507e-05, 'epoch': 1.779811848461734}
# ⏱️ Step 7100 - Elapsed: 62.58 min - Logs: {'loss': 0.4697, 'grad_norm': 0.2970470190048218, 'learning_rate': 7.029972403157268e-05, 'epoch': 1.8052377320111874}
# ⏱️ Step 7200 - Elapsed: 63.45 min - Logs: {'loss': 0.9498, 'grad_norm': 2.65840482711792, 'learning_rate': 6.880398522239028e-05, 'epoch': 1.8306636155606406}
# ⏱️ Step 7300 - Elapsed: 64.32 min - Logs: {'loss': 0.5853, 'grad_norm': 0.5290296077728271, 'learning_rate': 6.730824641320789e-05, 'epoch': 1.856089499110094}
# ⏱️ Step 7400 - Elapsed: 65.18 min - Logs: {'loss': 0.5282, 'grad_norm': 0.015709199011325836, 'learning_rate': 6.581250760402549e-05, 'epoch': 1.8815153826595474}
# ⏱️ Step 7500 - Elapsed: 66.05 min - Logs: {'loss': 0.6779, 'grad_norm': 0.8585811853408813, 'learning_rate': 6.431676879484309e-05, 'epoch': 1.9069412662090008}
# ⏱️ Step 7600 - Elapsed: 66.92 min - Logs: {'loss': 0.8236, 'grad_norm': 30.400768280029297, 'learning_rate': 6.282102998566068e-05, 'epoch': 1.9323671497584543}
# ⏱️ Step 7700 - Elapsed: 67.78 min - Logs: {'loss': 0.4555, 'grad_norm': 23.879146575927734, 'learning_rate': 6.132529117647829e-05, 'epoch': 1.9577930333079074}
# ⏱️ Step 7800 - Elapsed: 68.65 min - Logs: {'loss': 0.6819, 'grad_norm': 0.03747343271970749, 'learning_rate': 5.98295523672959e-05, 'epoch': 1.9832189168573608}
# ⏱️ Step 7866 - Elapsed: 70.23 min - Logs: {'eval_loss': 0.8840371966362, 'eval_f1': 0.8146881373073256, 'eval_runtime': 60.369, 'eval_samples_per_second': 16.3, 'eval_steps_per_second': 2.037, 'epoch': 2.0}
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# ⏱️ Step 7900 - Elapsed: 70.53 min - Logs: {'loss': 0.602, 'grad_norm': 0.09784363210201263, 'learning_rate': 5.83338135581135e-05, 'epoch': 2.008644800406814}
# ⏱️ Step 8000 - Elapsed: 71.4 min - Logs: {'loss': 0.641, 'grad_norm': 0.08299805968999863, 'learning_rate': 5.68380747489311e-05, 'epoch': 2.0340706839562674}
# ⏱️ Step 8100 - Elapsed: 72.26 min - Logs: {'loss': 0.5462, 'grad_norm': 0.05765227600932121, 'learning_rate': 5.53423359397487e-05, 'epoch': 2.059496567505721}
# ⏱️ Step 8200 - Elapsed: 73.12 min - Logs: {'loss': 0.6828, 'grad_norm': 0.02796316333115101, 'learning_rate': 5.384659713056631e-05, 'epoch': 2.0849224510551743}
# ⏱️ Step 8300 - Elapsed: 73.98 min - Logs: {'loss': 0.7305, 'grad_norm': 0.033547017723321915, 'learning_rate': 5.23508583213839e-05, 'epoch': 2.1103483346046277}
# ⏱️ Step 8400 - Elapsed: 74.84 min - Logs: {'loss': 0.5378, 'grad_norm': 11.05135726928711, 'learning_rate': 5.085511951220151e-05, 'epoch': 2.135774218154081}
# ⏱️ Step 8500 - Elapsed: 75.7 min - Logs: {'loss': 0.7206, 'grad_norm': 0.45655521750450134, 'learning_rate': 4.935938070301912e-05, 'epoch': 2.161200101703534}
# ⏱️ Step 8600 - Elapsed: 76.56 min - Logs: {'loss': 0.5374, 'grad_norm': 0.04824293032288551, 'learning_rate': 4.786364189383672e-05, 'epoch': 2.1866259852529875}
# ⏱️ Step 8700 - Elapsed: 77.42 min - Logs: {'loss': 0.4725, 'grad_norm': 0.335232675075531, 'learning_rate': 4.636790308465432e-05, 'epoch': 2.212051868802441}
# ⏱️ Step 8800 - Elapsed: 78.28 min - Logs: {'loss': 0.4848, 'grad_norm': 30.790733337402344, 'learning_rate': 4.487216427547192e-05, 'epoch': 2.2374777523518943}
# ⏱️ Step 8900 - Elapsed: 79.14 min - Logs: {'loss': 0.4172, 'grad_norm': 0.7468380928039551, 'learning_rate': 4.3376425466289525e-05, 'epoch': 2.2629036359013477}
# ⏱️ Step 9000 - Elapsed: 80.0 min - Logs: {'loss': 0.3717, 'grad_norm': 0.0813584104180336, 'learning_rate': 4.188068665710713e-05, 'epoch': 2.288329519450801}
# ⏱️ Step 9100 - Elapsed: 80.86 min - Logs: {'loss': 0.6023, 'grad_norm': 0.23227058351039886, 'learning_rate': 4.038494784792473e-05, 'epoch': 2.313755403000254}
# ⏱️ Step 9200 - Elapsed: 81.72 min - Logs: {'loss': 0.6465, 'grad_norm': 0.4375089704990387, 'learning_rate': 3.888920903874233e-05, 'epoch': 2.3391812865497075}
# ⏱️ Step 9300 - Elapsed: 82.58 min - Logs: {'loss': 0.7135, 'grad_norm': 79.2264404296875, 'learning_rate': 3.7393470229559934e-05, 'epoch': 2.364607170099161}
# ⏱️ Step 9400 - Elapsed: 83.43 min - Logs: {'loss': 0.4584, 'grad_norm': 7.831711769104004, 'learning_rate': 3.589773142037754e-05, 'epoch': 2.3900330536486143}
# ⏱️ Step 9500 - Elapsed: 84.29 min - Logs: {'loss': 0.412, 'grad_norm': 0.1511140614748001, 'learning_rate': 3.440199261119514e-05, 'epoch': 2.4154589371980677}
# ⏱️ Step 9600 - Elapsed: 85.15 min - Logs: {'loss': 0.5011, 'grad_norm': 0.26104989647865295, 'learning_rate': 3.2906253802012745e-05, 'epoch': 2.440884820747521}
# ⏱️ Step 9700 - Elapsed: 86.01 min - Logs: {'loss': 0.6082, 'grad_norm': 34.94627380371094, 'learning_rate': 3.141051499283034e-05, 'epoch': 2.4663107042969745}
# ⏱️ Step 9800 - Elapsed: 86.87 min - Logs: {'loss': 0.5298, 'grad_norm': 0.060313332825899124, 'learning_rate': 2.991477618364795e-05, 'epoch': 2.4917365878464275}
# ⏱️ Step 9900 - Elapsed: 87.73 min - Logs: {'loss': 0.7261, 'grad_norm': 47.01960372924805, 'learning_rate': 2.841903737446555e-05, 'epoch': 2.517162471395881}
# ⏱️ Step 10000 - Elapsed: 88.59 min - Logs: {'loss': 0.5002, 'grad_norm': 0.0318882092833519, 'learning_rate': 2.6923298565283156e-05, 'epoch': 2.5425883549453343}
# ⏱️ Step 10100 - Elapsed: 89.45 min - Logs: {'loss': 0.5189, 'grad_norm': 0.4374028444290161, 'learning_rate': 2.5427559756100757e-05, 'epoch': 2.5680142384947877}
# ⏱️ Step 10200 - Elapsed: 90.31 min - Logs: {'loss': 0.5107, 'grad_norm': 18.844636917114258, 'learning_rate': 2.393182094691836e-05, 'epoch': 2.593440122044241}
# ⏱️ Step 10300 - Elapsed: 91.17 min - Logs: {'loss': 0.725, 'grad_norm': 0.03610090911388397, 'learning_rate': 2.243608213773596e-05, 'epoch': 2.6188660055936945}
# ⏱️ Step 10400 - Elapsed: 92.03 min - Logs: {'loss': 0.6622, 'grad_norm': 1.0280134677886963, 'learning_rate': 2.0940343328553565e-05, 'epoch': 2.6442918891431475}
# ⏱️ Step 10500 - Elapsed: 92.89 min - Logs: {'loss': 0.487, 'grad_norm': 0.2624371647834778, 'learning_rate': 1.9444604519371165e-05, 'epoch': 2.669717772692601}
# ⏱️ Step 10600 - Elapsed: 93.75 min - Logs: {'loss': 0.6061, 'grad_norm': 0.239252969622612, 'learning_rate': 1.794886571018877e-05, 'epoch': 2.6951436562420543}
# ⏱️ Step 10700 - Elapsed: 94.61 min - Logs: {'loss': 0.4464, 'grad_norm': 3.7985920906066895, 'learning_rate': 1.6453126901006372e-05, 'epoch': 2.7205695397915077}
# ⏱️ Step 10800 - Elapsed: 95.47 min - Logs: {'loss': 0.3468, 'grad_norm': 1.478116750717163, 'learning_rate': 1.4957388091823974e-05, 'epoch': 2.745995423340961}
# ⏱️ Step 10900 - Elapsed: 96.33 min - Logs: {'loss': 0.3763, 'grad_norm': 6.1418304443359375, 'learning_rate': 1.3461649282641578e-05, 'epoch': 2.7714213068904145}
# ⏱️ Step 11000 - Elapsed: 97.19 min - Logs: {'loss': 0.5266, 'grad_norm': 0.28501832485198975, 'learning_rate': 1.196591047345918e-05, 'epoch': 2.796847190439868}
# ⏱️ Step 11100 - Elapsed: 98.05 min - Logs: {'loss': 0.6492, 'grad_norm': 51.77914810180664, 'learning_rate': 1.0470171664276782e-05, 'epoch': 2.8222730739893214}
# ⏱️ Step 11200 - Elapsed: 98.91 min - Logs: {'loss': 0.504, 'grad_norm': 0.022875433787703514, 'learning_rate': 8.974432855094384e-06, 'epoch': 2.8476989575387743}
# ⏱️ Step 11300 - Elapsed: 99.77 min - Logs: {'loss': 0.5442, 'grad_norm': 4.172382354736328, 'learning_rate': 7.478694045911987e-06, 'epoch': 2.8731248410882277}
# ⏱️ Step 11400 - Elapsed: 100.63 min - Logs: {'loss': 0.4319, 'grad_norm': 38.81859588623047, 'learning_rate': 5.98295523672959e-06, 'epoch': 2.898550724637681}
# ⏱️ Step 11500 - Elapsed: 101.49 min - Logs: {'loss': 0.5315, 'grad_norm': 0.7212247848510742, 'learning_rate': 4.487216427547192e-06, 'epoch': 2.9239766081871346}
# ⏱️ Step 11600 - Elapsed: 102.35 min - Logs: {'loss': 0.4602, 'grad_norm': 0.06301180273294449, 'learning_rate': 2.991477618364795e-06, 'epoch': 2.949402491736588}
# ⏱️ Step 11700 - Elapsed: 103.21 min - Logs: {'loss': 0.6495, 'grad_norm': 0.01790005713701248, 'learning_rate': 1.4957388091823975e-06, 'epoch': 2.974828375286041}
# ⏱️ Step 11799 - Elapsed: 105.05 min - Logs: {'eval_loss': 0.8307912945747375, 'eval_f1': 0.828066301754496, 'eval_runtime': 59.7764, 'eval_samples_per_second': 16.461, 'eval_steps_per_second': 2.058, 'epoch': 3.0}
# ⏱️ Step 11799 - Elapsed: 105.06 min - Logs: {'train_runtime': 6303.742, 'train_samples_per_second': 3.743, 'train_steps_per_second': 1.872, 'total_flos': 1.3251981172801536e+16, 'train_loss': 0.7177302524370404, 'epoch': 3.0}
# [I 2025-05-27 23:14:13,496] Trial 2 finished with value: 0.828066301754496 and parameters: {'learning_rate': 0.00017648222209543107, 'per_device_train_batch_size': 2, 'num_train_epochs': 3}. Best is trial 2 with value: 0.828066301754496.
# ✅ Done!
# ⏱️ Optuna tuning done in 336.29 minutes
# 🏆 Best trial params: {'learning_rate': 0.00017648222209543107, 'per_device_train_batch_size': 2, 'num_train_epochs': 3}

# %% [markdown]
# ### Saving the best parameters

# %%
print("🏆 Best trial F1 score:", best_trial.objective)
print("📋 Best trial hyperparameters:", best_trial.hyperparameters)
# Out:
# 🏆 Best trial F1 score: 0.828066301754496
# 📋 Best trial hyperparameters: {'learning_rate': 0.00017648222209543107, 'per_device_train_batch_size': 2, 'num_train_epochs': 3}

# %%
import json
# Save best params
with open("best_params_MISTRAL-v4.json", "w") as f:
    json.dump(best_trial.hyperparameters, f)

print("✅ Best hyperparameters saved.")
# Out:
# ✅ Best hyperparameters saved.

# %% [markdown]
# ### Final model

# %% [markdown]
# #### Merging Train and Validation Sets
#
# The training and validation datasets are merged into a single full training set.
# This allows the final model to be trained using all available labeled data for better performance, instead of wasting examples on separate validation.

# %%
# Merge train and validation splits
full_train_dataset = Dataset.from_dict({
    key: tokenized_dataset["train"][key] + tokenized_dataset["validation"][key]
    for key in tokenized_dataset["train"].features
})

# %% [markdown]
# ### Final version

# %% [markdown]
# In this final version, the model is fine-tuned using the best hyperparameters previously found with Optuna.
#
# Class imbalance is addressed by assigning a higher weight to the Neutral class during training.
#
# A custom WeightedTrainer is used to apply class weights correctly through a modified loss function (CrossEntropyLoss).
#
# The model is initialized with LoRA (Low-Rank Adaptation) on top of TinyMistral-248M, using 4-bit quantization to optimize memory usage.
#
# Training is done on the full training dataset, with no evaluation during training (evaluation_strategy="no"), to prevent data leakage.
#
# After training, predictions are made on the separate test set, and a threshold optimization is applied to better distinguish Neutral class predictions.
#
# Finally, classification metrics, a confusion matrix, and the weighted F1-score are printed to summarize the model's performance.

# %%
#  Imports
import torch
import json
import numpy as np
import time
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from torch import nn

#  Load Best Parameters
with open("best_params_MISTRAL.json", "r") as f:
    best_params = json.load(f)



#  Class weights
class_weights = torch.tensor([1.0, 1.0, 2.0], dtype=torch.float).to("cuda")  # Neutral weighted higher


#  Custom Trainer to inject class weights
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits, labels)
        return (loss, outputs) if return_outputs else loss

#  Model Init function
def model_init():
    base_model = AutoModelForSequenceClassification.from_pretrained(
        model_id,
        quantization_config=bnb_config,
        num_labels=3,
        trust_remote_code=True
    )
    base_model.config.pad_token_id = tokenizer.pad_token_id
    base_model = prepare_model_for_kbit_training(base_model)
    
    lora_config = LoraConfig(
        r=8,
        lora_alpha=16,
        target_modules=["q_proj", "v_proj"],
        lora_dropout=0.05,
        bias="none",
        task_type=TaskType.SEQ_CLS
    )
    model = get_peft_model(base_model, lora_config)
    return model

#  Training Args
final_training_args = TrainingArguments(
    output_dir="./final",
    eval_strategy="no",
    save_strategy="no",  
    learning_rate=best_params["learning_rate"],
    per_device_train_batch_size=best_params["per_device_train_batch_size"],
    num_train_epochs=3,
    report_to="none",
    fp16=False
)

#  Final Trainer
final_trainer = WeightedTrainer(
    model_init=model_init,
    args=final_training_args,
    train_dataset=full_train_dataset,  # <<< Full train
    tokenizer=tokenizer
)

#  Train
start = time.time()
final_trainer.train()
end = time.time()
print(f"\n✅ Final training completed in {round((end-start)/60, 2)} minutes.")

#  Save Model
final_trainer.save_model("finalBALANCE")
print(" Final model saved to 'finalBALANCE' folder.")

#  Predictions
predictions = final_trainer.predict(tokenized_dataset["test"])
probs = torch.softmax(torch.tensor(predictions.predictions), dim=1).numpy()
labels = predictions.label_ids

#  Auto Threshold Optimization
from scipy.optimize import minimize_scalar

def threshold_objective(thresh):
    preds = np.argmax(probs, axis=1)
    max_probs = np.max(probs, axis=1)
    preds[max_probs < thresh] = 2  # Force to Neutral if uncertain
    return -f1_score(labels, preds, average="weighted")

opt_result = minimize_scalar(threshold_objective, bounds=(0.3, 0.7), method="bounded")
best_thresh = opt_result.x
print(f"\n🔍 Best Neutral Threshold found: {round(best_thresh, 3)}")

#  Apply Best Threshold
preds = np.argmax(probs, axis=1)
max_probs = np.max(probs, axis=1)
preds[max_probs < best_thresh] = 2  # Again force Neutral

#  Print Metrics
print("\n📘 Classification Report (Final):")
print(classification_report(labels, preds, target_names=['Negative', 'Positive', 'Neutral']))

print("\n✅ Confusion Matrix:")
print(confusion_matrix(labels, preds))

final_f1 = f1_score(labels, preds, average="weighted")
print(f"\n🔴 Final Weighted F1 (with threshold): {round(final_f1, 4)}")
# Out:
# WARNING:tensorflow:From C:\Users\Alicia\AppData\Roaming\Python\Python39\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_2020\3935187034.py:66: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedTrainer.__init__`. Use `processing_class` instead.
#   final_trainer = WeightedTrainer(
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# Some weights of MistralForSequenceClassification were not initialized from the model checkpoint at Locutusque/TinyMistral-248M and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='13275' max='13275' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13275/13275 1:56:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.899100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.863000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.906200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.855300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.836100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.921800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.900500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.923600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.782200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.727100</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.763600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.778100</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.757300</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.725700</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.691600</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.658500</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.651600</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.630800</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.492900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.529000</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.597500</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.611000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.581900</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.557000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.503700</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.541300</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Final training completed in 116.38 minutes.
#  Final model saved to 'finalBALANCE' folder.
# 🔍 Best Neutral Threshold found: 0.341
#
# 📘 Classification Report (Final):
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.81      0.80       302
#     Positive       0.85      0.88      0.87       341
#      Neutral       0.44      0.40      0.42       167
#
#     accuracy                           0.75       810
#    macro avg       0.70      0.70      0.70       810
# weighted avg       0.75      0.75      0.75       810
#
#
# ✅ Confusion Matrix:
# [[245   3  54]
#  [ 11 299  31]
#  [ 52  48  67]]
#
# 🔴 Final Weighted F1 (with threshold): 0.7504

# %%
import torch
import torch.nn.functional as F
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from scipy.optimize import minimize_scalar

# === Predict on test set ===
predictions = final_trainer.predict(tokenized_dataset["test"])
logits = predictions.predictions
labels = predictions.label_ids

# === Apply softmax with temperature scaling ===
temperature = 2 
probs = F.softmax(torch.tensor(logits / temperature), dim=-1).numpy()

# === Define threshold optimization using confidence margin ===
def threshold_objective(margin):
    final_preds = []
    for p in probs:
        top2 = np.sort(p)[-2:]        # take two highest probs
        gap = top2[1] - top2[0]       # confidence gap
        if gap < margin:
            final_preds.append(2)     # force Neutral
        else:
            final_preds.append(np.argmax(p))
    return -f1_score(labels, final_preds, average="weighted")

# === Find best neutral margin ===
opt_result = minimize_scalar(threshold_objective, bounds=(0.05, 0.4), method="bounded")
neutral_margin = opt_result.x
print(f"\n🔍 Best Neutral Confidence Margin found: {round(neutral_margin, 3)}")

# === Apply margin to get final predictions ===
final_preds = []
for p in probs:
    top2 = np.sort(p)[-2:]
    gap = top2[1] - top2[0]
    if gap < neutral_margin:
        final_preds.append(2)
    else:
        final_preds.append(np.argmax(p))

# === Evaluation ===
print("\n📘 Classification Report (Confidence + Temperature):")
print(classification_report(labels, final_preds, target_names=["Negative", "Positive", "Neutral"]))

print("\n✅ Confusion Matrix:")
print(confusion_matrix(labels, final_preds))

final_f1 = f1_score(labels, final_preds, average="weighted")
print(f"\n🔴 Final Weighted F1 (with threshold): {round(final_f1, 4)}")
# Out:
# 🔍 Best Neutral Confidence Margin found: 0.157
#
# 📘 Classification Report (Confidence + Temperature):
#               precision    recall  f1-score   support
#
#     Negative       0.81      0.79      0.80       302
#     Positive       0.86      0.87      0.86       341
#      Neutral       0.44      0.43      0.43       167
#
#     accuracy                           0.75       810
#    macro avg       0.70      0.70      0.70       810
# weighted avg       0.75      0.75      0.75       810
#
#
# ✅ Confusion Matrix:
# [[240   3  59]
#  [ 10 297  34]
#  [ 48  47  72]]
#
# 🔴 Final Weighted F1 (with threshold): 0.7512

# %%
from sklearn.metrics import accuracy_score

final_accuracy = accuracy_score(labels, preds)

print(f"\n✅ Final Accuracy: {final_accuracy:.4f}")
print(f"✅ Final Weighted F1-score: {final_f1:.4f}")
# Out:
# ✅ Final Accuracy: 0.7543
# ✅ Final Weighted F1-score: 0.7512
