# %% [markdown]
# # Airlines Review

# %% [markdown]
# ---------------------

# %% [markdown]
# ## Phase 3 - LLM DistilRoBerta

# %% [markdown]
# ### Environment setup
#
# Setting Up Hugging Face to Use the E: Drive instead of the default C: drive.
# This saves local disk space and helps manage large files better.

# %%
# !pip install transformers datasets peft accelerate bitsandbytes 
import os

# Store all Hugging Face files on the E: drive
os.environ["HF_HOME"] = "E:/huggingface"
os.environ["TRANSFORMERS_CACHE"] = "E:/huggingface/transformers"
os.environ["HF_DATASETS_CACHE"] = "E:/huggingface/datasets"

# %%
import torch
print(torch.cuda.get_device_name(0))
print(f"Total VRAM: {round(torch.cuda.get_device_properties(0).total_memory / 1e9, 2)} GB")
# Out:
# NVIDIA GeForce GTX 1660 Ti
# Total VRAM: 6.44 GB

# %% [markdown]
# ### Load the model

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Model ID
model_id = "distilroberta-base"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token if tokenizer.eos_token else tokenizer.pad_token  # Ensure padding token exists

# Load pre-trained DistilRoBERTa model for 3-class classification
model = AutoModelForSequenceClassification.from_pretrained(
    model_id,
    num_labels=3
).to("cuda")

# Set pad token ID in model config
model.config.pad_token_id = tokenizer.pad_token_id

print("Pad token:", tokenizer.pad_token)
print("Pad token ID:", tokenizer.pad_token_id)
# Out:
# c:\Users\Alicia\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\utils\hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Pad token: </s>
# Pad token ID: 2

# %% [markdown]
# ### Load and Preprocess the Dataset

# %% [markdown]
# #### Loading the dataset:

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

# Load the dataset
df = pd.read_csv("./AirlinesReviews/data_phase1.csv", encoding='utf-8', on_bad_lines='skip')
df.head()
# Out:
#                Name Review Date             Airline Verified  \
# 0  Alison Soetantyo  2024-03-01  Singapore Airlines     True
# 1     Robert Watson  2024-02-21  Singapore Airlines     True
# 2             S Han  2024-02-20  Singapore Airlines     True
# 3          D Laynes  2024-02-19  Singapore Airlines     True
# 4         A Othman   2024-02-19  Singapore Airlines     True
#
#   Type of Traveller    Month Flown                         Route  \
# 0      Solo Leisure  December 2023          Jakarta to Singapore
# 1      Solo Leisure  February 2024           Phuket to Singapore
# 2    Family Leisure  February 2024        Siem Reap to Singapore
# 3      Solo Leisure  February 2024  Singapore to London Heathrow
# 4    Family Leisure  February 2024       Singapore to Phnom Penh
#
#             Class  Seat Comfort  Staff Service  Food & Beverages  \
# 0  Business Class             4              4                 4
# 1   Economy Class             5              3                 4
# 2   Economy Class             1              5                 2
# 3   Economy Class             5              5                 5
# 4   Economy Class             5              5                 5
#
#    Inflight Entertainment  Value For Money  Overall Rating Recommended  \
# 0                       4                4               9         yes
# 1                       4                1               3          no
# 2                       1                5              10         yes
# 3                       5                5              10         yes
# 4                       5                5              10         yes
#
#                                               Review Sentiment  Review_Length
# 0  Flight was amazing.   Flight was amazing. The ...  Positive             89
# 1  seats on this aircraft are dreadful .   Bookin...  Negative             49
# 2  Food was plentiful and tasty.   Excellent perf...  Positive             34
# 3  “how much food was available.  Pretty comforta...  Positive            171
# 4  “service was consistently good”.  The service ...  Positive             57

# %% [markdown]
# #### Preprocessing
#
# The dataset is cleaned and prepared by mapping sentiment labels (Positive, Negative, Neutral) to numerical values required for model training.
#
# Only the review text and corresponding label were retained, with the text column renamed to text for compatibility with the tokenizer.
#
# The "Review" column is renamed to "text" to match HuggingFace standards.
#
# The dataset is then split into training, validation, and test sets following an 80%-10%-10% split, ensuring random and reproducible partitions for fine-tuning the Mistral model.
#
# This simplified structure ensures the data is ready for tokenization and fine-tuning with the Mistral model.

# %%
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict
import pandas as pd

# 💬 Map sentiment labels to integers
label_map = {'Negative': 0, 'Positive': 1, 'Neutral': 2}
df = df[df['Sentiment'].isin(label_map.keys())]
df['label'] = df['Sentiment'].map(label_map)
df = df[['Review', 'label']].rename(columns={'Review': 'text'})

# === STEP 1: Split original imbalanced data FIRST ===
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df['label'],  # maintain class ratio in test
    random_state=42
)

# === STEP 2: Upsample Neutral class ONLY in training set ===
df_neg = train_df[train_df['label'] == 0]
df_pos = train_df[train_df['label'] == 1]
df_neu = train_df[train_df['label'] == 2]

# Match to largest class
target_size = max(len(df_neg), len(df_pos))
df_neu_upsampled = resample(
    df_neu,
    replace=True,
    n_samples=target_size,
    random_state=42
)

# Combine balanced training set
balanced_train_df = pd.concat([df_neg, df_pos, df_neu_upsampled]).sample(frac=1, random_state=42).reset_index(drop=True)

# === STEP 3: Convert to Hugging Face datasets ===
train_dataset = Dataset.from_pandas(balanced_train_df)
test_dataset = Dataset.from_pandas(test_df)

# === STEP 4: Split train into train/validation (10% val) ===
train_val_split = train_dataset.train_test_split(test_size=0.1111, seed=42)

# === STEP 5: Wrap in DatasetDict ===
dataset = DatasetDict({
    "train": train_val_split["train"],
    "validation": train_val_split["test"],
    "test": test_dataset  # ✅ original imbalanced test
})

# %% [markdown]
# ### Tokenize the Dataset
#
# The dataset is tokenized using the same tokenizer as the Mistral model:
#
# A custom tokenize function is applied to the "text" column, ensuring all sequences are padded or truncated to a maximum length of 512 tokens.
# The dataset is processed in batches for faster tokenization, preparing the text inputs for model training.

# %%
from transformers import AutoTokenizer
def tokenize(example):
    return tokenizer(example["text"], padding="max_length", truncation=True, max_length=512)

tokenized_dataset = dataset.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/7866 [00:00<?, ? examples/s]
# Map:   0%|          | 0/984 [00:00<?, ? examples/s]
# Map:   0%|          | 0/810 [00:00<?, ? examples/s]

# %% [markdown]
# ### Hyperparameter Search with Optuna
#
# Hyperparameter optimization is performed using Optuna:
#
# - The model is trained multiple times on the training set, and evaluated on the validation set, with the goal of maximizing the weighted F1-score.
#
# - Optuna explores different learning rates, batch sizes, and numbers of epochs to automatically find the best combination.
#
# - Training is monitored with a custom callback to track progress, and early stopping is used to avoid overfitting.
#
# - To address class imbalance in the dataset, class weights are computed automatically based on the frequency of each emotion label (Positive, Negative, Neutral).
# These weights are applied during training using a custom WeightedTrainer that modifies the loss function.
# This ensures that the model gives more importance to underrepresented classes and does not bias predictions toward majority classes.

# %%
import time
import optuna
import numpy as np
import torch
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight

from transformers import (
    TrainingArguments,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainerCallback,
    EarlyStoppingCallback,
)
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
from transformers import BitsAndBytesConfig
from torch import nn
from transformers import Trainer

#  Model Init function
def model_init():
    model = AutoModelForSequenceClassification.from_pretrained(
        model_id,
        num_labels=3
    )
    model.config.pad_token_id = tokenizer.pad_token_id
    return model 

#  Class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(df["label"]),
    y=df["label"]
)
class_weights = torch.tensor(class_weights, dtype=torch.float).to("cuda")

#  TRACK TIME PER TRIAL
class TrialProgressCallback(TrainerCallback):
    def __init__(self):
        self.start_time = None

    def on_train_begin(self, args, state, control, **kwargs):
        self.start_time = time.time()
        print(f"\n🚀 Starting trial at {time.strftime('%H:%M:%S')}")

    def on_log(self, args, state, control, logs=None, **kwargs):
        elapsed = time.time() - self.start_time
        print(f"⏱️ Step {state.global_step} - Elapsed: {round(elapsed/60, 2)} min - Logs: {logs}")

#  METRICS
def compute_metrics(pred):
    preds = pred.predictions.argmax(-1)
    return {"f1": f1_score(pred.label_ids, preds, average="weighted")}

#  MODEL INIT 


#  OPTUNA SEARCH SPACE
def optuna_hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 2e-5, 5e-4, log=True),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [2, 4]),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 2, 3)
    }

#  Custom Trainer with class weights
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits, labels)
        return (loss, outputs) if return_outputs else loss



#  TRAINING ARGS
training_args = TrainingArguments(
    output_dir="./optuna_output",
    eval_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=1,
    metric_for_best_model="f1",
    load_best_model_at_end=True,
    report_to="none",
    logging_dir="./logs",
    logging_strategy="steps",
    logging_steps=100,
    fp16=False
)

#  TRAINER with everything
trainer = WeightedTrainer(
    model_init=model_init,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[
        TrialProgressCallback(),
        EarlyStoppingCallback(early_stopping_patience=2)
    ]
)

#  RUN OPTUNA
start = time.time()

best_trial = trainer.hyperparameter_search(
    direction="maximize",
    hp_space=optuna_hp_space,
    n_trials=3
)

end = time.time()

print("\n✅ Done!")
print(f"⏱️ Optuna tuning done in {round((end - start)/60, 2)} minutes")
print("🏆 Best trial params:", best_trial.hyperparameters)
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_792\3273194492.py:94: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedTrainer.__init__`. Use `processing_class` instead.
#   trainer = WeightedTrainer(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [I 2025-05-29 15:46:02,018] A new study created in memory with name: no-name-940362dd-c425-4518-9dd7-e41d503a6e5b
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting trial at 15:46:02
#     <div>
#
#       <progress value='11799' max='11799' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11799/11799 34:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.077700</td>
#       <td>0.970283</td>
#       <td>0.464428</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.101800</td>
#       <td>0.974688</td>
#       <td>0.658450</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.003400</td>
#       <td>1.206006</td>
#       <td>0.699980</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 0.32 min - Logs: {'loss': 1.217, 'grad_norm': 2.8954014778137207, 'learning_rate': 8.528210475650763e-05, 'epoch': 0.025425883549453344}
# ⏱️ Step 200 - Elapsed: 0.65 min - Logs: {'loss': 1.109, 'grad_norm': 1.9583098888397217, 'learning_rate': 8.455319787824688e-05, 'epoch': 0.05085176709890669}
# ⏱️ Step 300 - Elapsed: 1.01 min - Logs: {'loss': 1.0758, 'grad_norm': 4.057555675506592, 'learning_rate': 8.382429099998613e-05, 'epoch': 0.07627765064836003}
# ⏱️ Step 400 - Elapsed: 1.29 min - Logs: {'loss': 1.1337, 'grad_norm': 12.821508407592773, 'learning_rate': 8.309538412172538e-05, 'epoch': 0.10170353419781338}
# ⏱️ Step 500 - Elapsed: 1.59 min - Logs: {'loss': 1.0573, 'grad_norm': 20.15970230102539, 'learning_rate': 8.236647724346464e-05, 'epoch': 0.12712941774726672}
# ⏱️ Step 600 - Elapsed: 1.9 min - Logs: {'loss': 1.0254, 'grad_norm': 2.6757819652557373, 'learning_rate': 8.163757036520388e-05, 'epoch': 0.15255530129672007}
# ⏱️ Step 700 - Elapsed: 2.22 min - Logs: {'loss': 1.0594, 'grad_norm': 5.968093395233154, 'learning_rate': 8.090866348694314e-05, 'epoch': 0.1779811848461734}
# ⏱️ Step 800 - Elapsed: 2.55 min - Logs: {'loss': 1.1417, 'grad_norm': 7.274186611175537, 'learning_rate': 8.01797566086824e-05, 'epoch': 0.20340706839562675}
# ⏱️ Step 900 - Elapsed: 2.9 min - Logs: {'loss': 0.9015, 'grad_norm': 7.485896587371826, 'learning_rate': 7.945084973042164e-05, 'epoch': 0.2288329519450801}
# ⏱️ Step 1000 - Elapsed: 3.23 min - Logs: {'loss': 0.9931, 'grad_norm': 4.20202112197876, 'learning_rate': 7.87219428521609e-05, 'epoch': 0.25425883549453343}
# ⏱️ Step 1100 - Elapsed: 3.55 min - Logs: {'loss': 1.0237, 'grad_norm': 1.9747177362442017, 'learning_rate': 7.799303597390014e-05, 'epoch': 0.2796847190439868}
# ⏱️ Step 1200 - Elapsed: 3.87 min - Logs: {'loss': 0.9834, 'grad_norm': 0.6529848575592041, 'learning_rate': 7.72641290956394e-05, 'epoch': 0.30511060259344014}
# ⏱️ Step 1300 - Elapsed: 4.2 min - Logs: {'loss': 1.1663, 'grad_norm': 2.7490878105163574, 'learning_rate': 7.653522221737864e-05, 'epoch': 0.3305364861428935}
# ⏱️ Step 1400 - Elapsed: 4.53 min - Logs: {'loss': 1.1099, 'grad_norm': 7.642007350921631, 'learning_rate': 7.58063153391179e-05, 'epoch': 0.3559623696923468}
# ⏱️ Step 1500 - Elapsed: 4.85 min - Logs: {'loss': 1.0345, 'grad_norm': 55.175907135009766, 'learning_rate': 7.507740846085715e-05, 'epoch': 0.38138825324180015}
# ⏱️ Step 1600 - Elapsed: 5.17 min - Logs: {'loss': 1.0383, 'grad_norm': 5.020969867706299, 'learning_rate': 7.43485015825964e-05, 'epoch': 0.4068141367912535}
# ⏱️ Step 1700 - Elapsed: 5.51 min - Logs: {'loss': 0.9426, 'grad_norm': 4.600982189178467, 'learning_rate': 7.361959470433565e-05, 'epoch': 0.43224002034070685}
# ⏱️ Step 1800 - Elapsed: 5.84 min - Logs: {'loss': 0.9974, 'grad_norm': 13.384541511535645, 'learning_rate': 7.28906878260749e-05, 'epoch': 0.4576659038901602}
# ⏱️ Step 1900 - Elapsed: 6.14 min - Logs: {'loss': 0.9762, 'grad_norm': 7.572619915008545, 'learning_rate': 7.216178094781415e-05, 'epoch': 0.4830917874396135}
# ⏱️ Step 2000 - Elapsed: 6.44 min - Logs: {'loss': 1.0353, 'grad_norm': 4.982883930206299, 'learning_rate': 7.143287406955339e-05, 'epoch': 0.5085176709890669}
# ⏱️ Step 2100 - Elapsed: 6.72 min - Logs: {'loss': 1.037, 'grad_norm': 4.848772048950195, 'learning_rate': 7.070396719129265e-05, 'epoch': 0.5339435545385202}
# ⏱️ Step 2200 - Elapsed: 6.99 min - Logs: {'loss': 0.9274, 'grad_norm': 2.663419723510742, 'learning_rate': 6.99750603130319e-05, 'epoch': 0.5593694380879736}
# ⏱️ Step 2300 - Elapsed: 7.27 min - Logs: {'loss': 0.9144, 'grad_norm': 3.2150368690490723, 'learning_rate': 6.924615343477116e-05, 'epoch': 0.5847953216374269}
# ⏱️ Step 2400 - Elapsed: 7.55 min - Logs: {'loss': 0.8556, 'grad_norm': 24.864187240600586, 'learning_rate': 6.85172465565104e-05, 'epoch': 0.6102212051868803}
# ⏱️ Step 2500 - Elapsed: 7.82 min - Logs: {'loss': 0.9407, 'grad_norm': 4.647208213806152, 'learning_rate': 6.778833967824966e-05, 'epoch': 0.6356470887363336}
# ⏱️ Step 2600 - Elapsed: 8.09 min - Logs: {'loss': 1.0173, 'grad_norm': 3.4825332164764404, 'learning_rate': 6.70594327999889e-05, 'epoch': 0.661072972285787}
# ⏱️ Step 2700 - Elapsed: 8.36 min - Logs: {'loss': 0.9791, 'grad_norm': 13.178522109985352, 'learning_rate': 6.633052592172816e-05, 'epoch': 0.6864988558352403}
# ⏱️ Step 2800 - Elapsed: 8.63 min - Logs: {'loss': 1.1361, 'grad_norm': 5.495819568634033, 'learning_rate': 6.56016190434674e-05, 'epoch': 0.7119247393846936}
# ⏱️ Step 2900 - Elapsed: 8.91 min - Logs: {'loss': 1.0912, 'grad_norm': 2.6759469509124756, 'learning_rate': 6.487271216520666e-05, 'epoch': 0.737350622934147}
# ⏱️ Step 3000 - Elapsed: 9.19 min - Logs: {'loss': 1.1178, 'grad_norm': 12.5042085647583, 'learning_rate': 6.414380528694592e-05, 'epoch': 0.7627765064836003}
# ⏱️ Step 3100 - Elapsed: 9.46 min - Logs: {'loss': 1.075, 'grad_norm': 1.8636776208877563, 'learning_rate': 6.341489840868516e-05, 'epoch': 0.7882023900330537}
# ⏱️ Step 3200 - Elapsed: 9.73 min - Logs: {'loss': 1.0282, 'grad_norm': 8.40662956237793, 'learning_rate': 6.268599153042442e-05, 'epoch': 0.813628273582507}
# ⏱️ Step 3300 - Elapsed: 10.0 min - Logs: {'loss': 0.9513, 'grad_norm': 8.047189712524414, 'learning_rate': 6.195708465216366e-05, 'epoch': 0.8390541571319603}
# ⏱️ Step 3400 - Elapsed: 10.27 min - Logs: {'loss': 0.9927, 'grad_norm': 7.747314453125, 'learning_rate': 6.122817777390292e-05, 'epoch': 0.8644800406814137}
# ⏱️ Step 3500 - Elapsed: 10.54 min - Logs: {'loss': 1.0065, 'grad_norm': 2.2546093463897705, 'learning_rate': 6.0499270895642166e-05, 'epoch': 0.889905924230867}
# ⏱️ Step 3600 - Elapsed: 10.82 min - Logs: {'loss': 1.0681, 'grad_norm': 3.748385190963745, 'learning_rate': 5.9770364017381415e-05, 'epoch': 0.9153318077803204}
# ⏱️ Step 3700 - Elapsed: 11.09 min - Logs: {'loss': 1.0523, 'grad_norm': 2.458483934402466, 'learning_rate': 5.904145713912067e-05, 'epoch': 0.9407576913297737}
# ⏱️ Step 3800 - Elapsed: 11.36 min - Logs: {'loss': 1.0815, 'grad_norm': 5.710348606109619, 'learning_rate': 5.831255026085992e-05, 'epoch': 0.966183574879227}
# ⏱️ Step 3900 - Elapsed: 11.64 min - Logs: {'loss': 1.0777, 'grad_norm': 15.580222129821777, 'learning_rate': 5.758364338259917e-05, 'epoch': 0.9916094584286804}
# ⏱️ Step 3933 - Elapsed: 12.04 min - Logs: {'eval_loss': 0.9702832102775574, 'eval_f1': 0.46442795015924526, 'eval_runtime': 18.4018, 'eval_samples_per_second': 53.473, 'eval_steps_per_second': 6.684, 'epoch': 1.0}
# ⏱️ Step 4000 - Elapsed: 12.27 min - Logs: {'loss': 1.0673, 'grad_norm': 11.610542297363281, 'learning_rate': 5.685473650433843e-05, 'epoch': 1.0170353419781337}
# ⏱️ Step 4100 - Elapsed: 12.54 min - Logs: {'loss': 0.9246, 'grad_norm': 2.6118743419647217, 'learning_rate': 5.612582962607767e-05, 'epoch': 1.0424612255275871}
# ⏱️ Step 4200 - Elapsed: 12.81 min - Logs: {'loss': 0.976, 'grad_norm': 3.404416561126709, 'learning_rate': 5.539692274781692e-05, 'epoch': 1.0678871090770405}
# ⏱️ Step 4300 - Elapsed: 13.09 min - Logs: {'loss': 0.9695, 'grad_norm': 3.6211423873901367, 'learning_rate': 5.466801586955617e-05, 'epoch': 1.0933129926264937}
# ⏱️ Step 4400 - Elapsed: 13.37 min - Logs: {'loss': 0.8487, 'grad_norm': 8.151444435119629, 'learning_rate': 5.3939108991295427e-05, 'epoch': 1.1187388761759471}
# ⏱️ Step 4500 - Elapsed: 13.63 min - Logs: {'loss': 0.9852, 'grad_norm': 11.834656715393066, 'learning_rate': 5.3210202113034676e-05, 'epoch': 1.1441647597254005}
# ⏱️ Step 4600 - Elapsed: 13.9 min - Logs: {'loss': 0.9486, 'grad_norm': 7.235942363739014, 'learning_rate': 5.248129523477393e-05, 'epoch': 1.1695906432748537}
# ⏱️ Step 4700 - Elapsed: 14.18 min - Logs: {'loss': 0.8575, 'grad_norm': 0.42407068610191345, 'learning_rate': 5.175238835651318e-05, 'epoch': 1.1950165268243071}
# ⏱️ Step 4800 - Elapsed: 14.47 min - Logs: {'loss': 1.107, 'grad_norm': 2.588886260986328, 'learning_rate': 5.1023481478252425e-05, 'epoch': 1.2204424103737606}
# ⏱️ Step 4900 - Elapsed: 14.74 min - Logs: {'loss': 0.974, 'grad_norm': 5.639651298522949, 'learning_rate': 5.0294574599991675e-05, 'epoch': 1.2458682939232137}
# ⏱️ Step 5000 - Elapsed: 15.01 min - Logs: {'loss': 0.9743, 'grad_norm': 12.541281700134277, 'learning_rate': 4.956566772173093e-05, 'epoch': 1.2712941774726672}
# ⏱️ Step 5100 - Elapsed: 15.29 min - Logs: {'loss': 0.9421, 'grad_norm': 3.338888168334961, 'learning_rate': 4.883676084347018e-05, 'epoch': 1.2967200610221206}
# ⏱️ Step 5200 - Elapsed: 15.56 min - Logs: {'loss': 1.1168, 'grad_norm': 1.8691176176071167, 'learning_rate': 4.810785396520944e-05, 'epoch': 1.3221459445715738}
# ⏱️ Step 5300 - Elapsed: 15.83 min - Logs: {'loss': 0.8888, 'grad_norm': 2.2021431922912598, 'learning_rate': 4.737894708694869e-05, 'epoch': 1.3475718281210272}
# ⏱️ Step 5400 - Elapsed: 16.11 min - Logs: {'loss': 0.9391, 'grad_norm': 1.6800034046173096, 'learning_rate': 4.665004020868794e-05, 'epoch': 1.3729977116704806}
# ⏱️ Step 5500 - Elapsed: 16.38 min - Logs: {'loss': 0.9964, 'grad_norm': 3.368556499481201, 'learning_rate': 4.592113333042718e-05, 'epoch': 1.398423595219934}
# ⏱️ Step 5600 - Elapsed: 16.65 min - Logs: {'loss': 0.8624, 'grad_norm': 4.087730407714844, 'learning_rate': 4.519222645216644e-05, 'epoch': 1.4238494787693872}
# ⏱️ Step 5700 - Elapsed: 16.92 min - Logs: {'loss': 0.9286, 'grad_norm': 7.850000858306885, 'learning_rate': 4.4463319573905686e-05, 'epoch': 1.4492753623188406}
# ⏱️ Step 5800 - Elapsed: 17.2 min - Logs: {'loss': 0.9534, 'grad_norm': 9.767955780029297, 'learning_rate': 4.3734412695644936e-05, 'epoch': 1.474701245868294}
# ⏱️ Step 5900 - Elapsed: 17.47 min - Logs: {'loss': 0.7996, 'grad_norm': 4.176197528839111, 'learning_rate': 4.300550581738419e-05, 'epoch': 1.5001271294177472}
# ⏱️ Step 6000 - Elapsed: 17.73 min - Logs: {'loss': 0.9238, 'grad_norm': 0.9891381859779358, 'learning_rate': 4.227659893912344e-05, 'epoch': 1.5255530129672006}
# ⏱️ Step 6100 - Elapsed: 18.0 min - Logs: {'loss': 0.9608, 'grad_norm': 6.174410820007324, 'learning_rate': 4.154769206086269e-05, 'epoch': 1.550978896516654}
# ⏱️ Step 6200 - Elapsed: 18.26 min - Logs: {'loss': 0.943, 'grad_norm': 11.41791820526123, 'learning_rate': 4.081878518260194e-05, 'epoch': 1.5764047800661074}
# ⏱️ Step 6300 - Elapsed: 18.54 min - Logs: {'loss': 0.8876, 'grad_norm': 4.26564359664917, 'learning_rate': 4.00898783043412e-05, 'epoch': 1.6018306636155606}
# ⏱️ Step 6400 - Elapsed: 18.84 min - Logs: {'loss': 0.8908, 'grad_norm': 15.78390884399414, 'learning_rate': 3.936097142608045e-05, 'epoch': 1.627256547165014}
# ⏱️ Step 6500 - Elapsed: 19.14 min - Logs: {'loss': 0.9308, 'grad_norm': 3.4178833961486816, 'learning_rate': 3.86320645478197e-05, 'epoch': 1.6526824307144672}
# ⏱️ Step 6600 - Elapsed: 19.42 min - Logs: {'loss': 1.0336, 'grad_norm': 4.1816020011901855, 'learning_rate': 3.790315766955895e-05, 'epoch': 1.6781083142639206}
# ⏱️ Step 6700 - Elapsed: 19.69 min - Logs: {'loss': 0.826, 'grad_norm': 2.8557305335998535, 'learning_rate': 3.71742507912982e-05, 'epoch': 1.703534197813374}
# ⏱️ Step 6800 - Elapsed: 19.95 min - Logs: {'loss': 0.7659, 'grad_norm': 4.30072546005249, 'learning_rate': 3.644534391303745e-05, 'epoch': 1.7289600813628274}
# ⏱️ Step 6900 - Elapsed: 20.22 min - Logs: {'loss': 0.7788, 'grad_norm': 5.909420013427734, 'learning_rate': 3.5716437034776696e-05, 'epoch': 1.7543859649122808}
# ⏱️ Step 7000 - Elapsed: 20.49 min - Logs: {'loss': 0.8375, 'grad_norm': 1.2456415891647339, 'learning_rate': 3.498753015651595e-05, 'epoch': 1.779811848461734}
# ⏱️ Step 7100 - Elapsed: 20.75 min - Logs: {'loss': 1.018, 'grad_norm': 10.079535484313965, 'learning_rate': 3.42586232782552e-05, 'epoch': 1.8052377320111874}
# ⏱️ Step 7200 - Elapsed: 21.02 min - Logs: {'loss': 1.1673, 'grad_norm': 1.9350014925003052, 'learning_rate': 3.352971639999445e-05, 'epoch': 1.8306636155606406}
# ⏱️ Step 7300 - Elapsed: 21.29 min - Logs: {'loss': 0.9437, 'grad_norm': 1.21052885055542, 'learning_rate': 3.28008095217337e-05, 'epoch': 1.856089499110094}
# ⏱️ Step 7400 - Elapsed: 21.55 min - Logs: {'loss': 0.7784, 'grad_norm': 1.7473454475402832, 'learning_rate': 3.207190264347296e-05, 'epoch': 1.8815153826595474}
# ⏱️ Step 7500 - Elapsed: 21.81 min - Logs: {'loss': 1.0301, 'grad_norm': 2.7408511638641357, 'learning_rate': 3.134299576521221e-05, 'epoch': 1.9069412662090008}
# ⏱️ Step 7600 - Elapsed: 22.07 min - Logs: {'loss': 1.0275, 'grad_norm': 9.091794967651367, 'learning_rate': 3.061408888695146e-05, 'epoch': 1.9323671497584543}
# ⏱️ Step 7700 - Elapsed: 22.34 min - Logs: {'loss': 0.8176, 'grad_norm': 9.744349479675293, 'learning_rate': 2.9885182008690708e-05, 'epoch': 1.9577930333079074}
# ⏱️ Step 7800 - Elapsed: 22.62 min - Logs: {'loss': 1.1018, 'grad_norm': 0.5537919402122498, 'learning_rate': 2.915627513042996e-05, 'epoch': 1.9832189168573608}
# ⏱️ Step 7866 - Elapsed: 23.1 min - Logs: {'eval_loss': 0.9746882319450378, 'eval_f1': 0.6584499836027474, 'eval_runtime': 18.274, 'eval_samples_per_second': 53.847, 'eval_steps_per_second': 6.731, 'epoch': 2.0}
# ⏱️ Step 7900 - Elapsed: 23.22 min - Logs: {'loss': 0.9788, 'grad_norm': 3.8132193088531494, 'learning_rate': 2.8427368252169214e-05, 'epoch': 2.008644800406814}
# ⏱️ Step 8000 - Elapsed: 23.47 min - Logs: {'loss': 0.9911, 'grad_norm': 7.205570220947266, 'learning_rate': 2.769846137390846e-05, 'epoch': 2.0340706839562674}
# ⏱️ Step 8100 - Elapsed: 23.73 min - Logs: {'loss': 0.944, 'grad_norm': 0.5747594833374023, 'learning_rate': 2.6969554495647713e-05, 'epoch': 2.059496567505721}
# ⏱️ Step 8200 - Elapsed: 23.98 min - Logs: {'loss': 0.9033, 'grad_norm': 0.5033081769943237, 'learning_rate': 2.6240647617386966e-05, 'epoch': 2.0849224510551743}
# ⏱️ Step 8300 - Elapsed: 24.24 min - Logs: {'loss': 0.8801, 'grad_norm': 0.7409961223602295, 'learning_rate': 2.5511740739126213e-05, 'epoch': 2.1103483346046277}
# ⏱️ Step 8400 - Elapsed: 24.52 min - Logs: {'loss': 0.7908, 'grad_norm': 14.37440013885498, 'learning_rate': 2.4782833860865466e-05, 'epoch': 2.135774218154081}
# ⏱️ Step 8500 - Elapsed: 24.8 min - Logs: {'loss': 0.8117, 'grad_norm': 1.5283154249191284, 'learning_rate': 2.405392698260472e-05, 'epoch': 2.161200101703534}
# ⏱️ Step 8600 - Elapsed: 25.09 min - Logs: {'loss': 1.0568, 'grad_norm': 1.685240626335144, 'learning_rate': 2.332502010434397e-05, 'epoch': 2.1866259852529875}
# ⏱️ Step 8700 - Elapsed: 25.38 min - Logs: {'loss': 0.9329, 'grad_norm': 16.103641510009766, 'learning_rate': 2.259611322608322e-05, 'epoch': 2.212051868802441}
# ⏱️ Step 8800 - Elapsed: 25.67 min - Logs: {'loss': 0.8025, 'grad_norm': 18.679033279418945, 'learning_rate': 2.1867206347822468e-05, 'epoch': 2.2374777523518943}
# ⏱️ Step 8900 - Elapsed: 25.96 min - Logs: {'loss': 0.9659, 'grad_norm': 8.119627952575684, 'learning_rate': 2.113829946956172e-05, 'epoch': 2.2629036359013477}
# ⏱️ Step 9000 - Elapsed: 26.25 min - Logs: {'loss': 0.8795, 'grad_norm': 8.022961616516113, 'learning_rate': 2.040939259130097e-05, 'epoch': 2.288329519450801}
# ⏱️ Step 9100 - Elapsed: 26.54 min - Logs: {'loss': 1.0819, 'grad_norm': 12.482778549194336, 'learning_rate': 1.9680485713040224e-05, 'epoch': 2.313755403000254}
# ⏱️ Step 9200 - Elapsed: 26.83 min - Logs: {'loss': 0.9832, 'grad_norm': 2.0884077548980713, 'learning_rate': 1.8951578834779474e-05, 'epoch': 2.3391812865497075}
# ⏱️ Step 9300 - Elapsed: 27.13 min - Logs: {'loss': 0.9886, 'grad_norm': 16.842676162719727, 'learning_rate': 1.8222671956518723e-05, 'epoch': 2.364607170099161}
# ⏱️ Step 9400 - Elapsed: 27.42 min - Logs: {'loss': 0.8745, 'grad_norm': 0.632939338684082, 'learning_rate': 1.7493765078257976e-05, 'epoch': 2.3900330536486143}
# ⏱️ Step 9500 - Elapsed: 27.71 min - Logs: {'loss': 0.8391, 'grad_norm': 0.7157464623451233, 'learning_rate': 1.6764858199997226e-05, 'epoch': 2.4154589371980677}
# ⏱️ Step 9600 - Elapsed: 28.01 min - Logs: {'loss': 0.9806, 'grad_norm': 11.534041404724121, 'learning_rate': 1.603595132173648e-05, 'epoch': 2.440884820747521}
# ⏱️ Step 9700 - Elapsed: 28.3 min - Logs: {'loss': 0.9188, 'grad_norm': 16.374116897583008, 'learning_rate': 1.530704444347573e-05, 'epoch': 2.4663107042969745}
# ⏱️ Step 9800 - Elapsed: 28.58 min - Logs: {'loss': 1.012, 'grad_norm': 0.5872009992599487, 'learning_rate': 1.457813756521498e-05, 'epoch': 2.4917365878464275}
# ⏱️ Step 9900 - Elapsed: 28.87 min - Logs: {'loss': 0.8254, 'grad_norm': 14.347293853759766, 'learning_rate': 1.384923068695423e-05, 'epoch': 2.517162471395881}
# ⏱️ Step 10000 - Elapsed: 29.16 min - Logs: {'loss': 0.9355, 'grad_norm': 0.5127031803131104, 'learning_rate': 1.3120323808693483e-05, 'epoch': 2.5425883549453343}
# ⏱️ Step 10100 - Elapsed: 29.45 min - Logs: {'loss': 0.9977, 'grad_norm': 18.248157501220703, 'learning_rate': 1.2391416930432733e-05, 'epoch': 2.5680142384947877}
# ⏱️ Step 10200 - Elapsed: 29.75 min - Logs: {'loss': 1.022, 'grad_norm': 12.507643699645996, 'learning_rate': 1.1662510052171984e-05, 'epoch': 2.593440122044241}
# ⏱️ Step 10300 - Elapsed: 30.02 min - Logs: {'loss': 1.0229, 'grad_norm': 15.773107528686523, 'learning_rate': 1.0933603173911234e-05, 'epoch': 2.6188660055936945}
# ⏱️ Step 10400 - Elapsed: 30.28 min - Logs: {'loss': 1.1172, 'grad_norm': 17.385000228881836, 'learning_rate': 1.0204696295650485e-05, 'epoch': 2.6442918891431475}
# ⏱️ Step 10500 - Elapsed: 30.56 min - Logs: {'loss': 0.9438, 'grad_norm': 12.279122352600098, 'learning_rate': 9.475789417389737e-06, 'epoch': 2.669717772692601}
# ⏱️ Step 10600 - Elapsed: 30.84 min - Logs: {'loss': 0.9838, 'grad_norm': 0.5752037167549133, 'learning_rate': 8.746882539128988e-06, 'epoch': 2.6951436562420543}
# ⏱️ Step 10700 - Elapsed: 31.12 min - Logs: {'loss': 0.8799, 'grad_norm': 4.227012634277344, 'learning_rate': 8.01797566086824e-06, 'epoch': 2.7205695397915077}
# ⏱️ Step 10800 - Elapsed: 31.4 min - Logs: {'loss': 0.8411, 'grad_norm': 16.497312545776367, 'learning_rate': 7.28906878260749e-06, 'epoch': 2.745995423340961}
# ⏱️ Step 10900 - Elapsed: 31.66 min - Logs: {'loss': 1.0318, 'grad_norm': 16.447399139404297, 'learning_rate': 6.560161904346742e-06, 'epoch': 2.7714213068904145}
# ⏱️ Step 11000 - Elapsed: 31.93 min - Logs: {'loss': 0.9238, 'grad_norm': 0.5758227705955505, 'learning_rate': 5.831255026085992e-06, 'epoch': 2.796847190439868}
# ⏱️ Step 11100 - Elapsed: 32.21 min - Logs: {'loss': 1.207, 'grad_norm': 0.8283004760742188, 'learning_rate': 5.102348147825243e-06, 'epoch': 2.8222730739893214}
# ⏱️ Step 11200 - Elapsed: 32.49 min - Logs: {'loss': 1.1356, 'grad_norm': 0.8208674192428589, 'learning_rate': 4.373441269564494e-06, 'epoch': 2.8476989575387743}
# ⏱️ Step 11300 - Elapsed: 32.78 min - Logs: {'loss': 0.9676, 'grad_norm': 0.44413042068481445, 'learning_rate': 3.644534391303745e-06, 'epoch': 2.8731248410882277}
# ⏱️ Step 11400 - Elapsed: 33.07 min - Logs: {'loss': 1.0602, 'grad_norm': 1.7980271577835083, 'learning_rate': 2.915627513042996e-06, 'epoch': 2.898550724637681}
# ⏱️ Step 11500 - Elapsed: 33.33 min - Logs: {'loss': 1.1122, 'grad_norm': 16.06157684326172, 'learning_rate': 2.186720634782247e-06, 'epoch': 2.9239766081871346}
# ⏱️ Step 11600 - Elapsed: 33.62 min - Logs: {'loss': 1.1369, 'grad_norm': 2.344238042831421, 'learning_rate': 1.457813756521498e-06, 'epoch': 2.949402491736588}
# ⏱️ Step 11700 - Elapsed: 33.89 min - Logs: {'loss': 1.0034, 'grad_norm': 0.7676747441291809, 'learning_rate': 7.28906878260749e-07, 'epoch': 2.974828375286041}
# ⏱️ Step 11799 - Elapsed: 34.46 min - Logs: {'eval_loss': 1.2060062885284424, 'eval_f1': 0.6999803181241854, 'eval_runtime': 17.9691, 'eval_samples_per_second': 54.761, 'eval_steps_per_second': 6.845, 'epoch': 3.0}
# ⏱️ Step 11799 - Elapsed: 34.49 min - Logs: {'train_runtime': 2069.581, 'train_samples_per_second': 11.402, 'train_steps_per_second': 5.701, 'total_flos': 3126021420644352.0, 'train_loss': 0.9815201677299271, 'epoch': 3.0}
# [I 2025-05-29 16:20:33,317] Trial 0 finished with value: 0.6999803181241854 and parameters: {'learning_rate': 8.600372256598577e-05, 'per_device_train_batch_size': 2, 'num_train_epochs': 3}. Best is trial 0 with value: 0.6999803181241854.
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting trial at 16:20:34
#     <div>
#
#       <progress value='7866' max='7866' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7866/7866 21:29, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.021700</td>
#       <td>0.883136</td>
#       <td>0.802450</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.789400</td>
#       <td>0.743955</td>
#       <td>0.856660</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 0.28 min - Logs: {'loss': 1.1177, 'grad_norm': 11.837272644042969, 'learning_rate': 3.758016435850544e-05, 'epoch': 0.025425883549453344}
# ⏱️ Step 200 - Elapsed: 0.57 min - Logs: {'loss': 1.2333, 'grad_norm': 2.238924503326416, 'learning_rate': 3.709632034719469e-05, 'epoch': 0.05085176709890669}
# ⏱️ Step 300 - Elapsed: 0.85 min - Logs: {'loss': 1.0103, 'grad_norm': 4.458409309387207, 'learning_rate': 3.661247633588395e-05, 'epoch': 0.07627765064836003}
# ⏱️ Step 400 - Elapsed: 1.12 min - Logs: {'loss': 0.8278, 'grad_norm': 0.9361220598220825, 'learning_rate': 3.612863232457321e-05, 'epoch': 0.10170353419781338}
# ⏱️ Step 500 - Elapsed: 1.4 min - Logs: {'loss': 1.0554, 'grad_norm': 8.248473167419434, 'learning_rate': 3.5644788313262466e-05, 'epoch': 0.12712941774726672}
# ⏱️ Step 600 - Elapsed: 1.66 min - Logs: {'loss': 1.0175, 'grad_norm': 18.788837432861328, 'learning_rate': 3.5160944301951726e-05, 'epoch': 0.15255530129672007}
# ⏱️ Step 700 - Elapsed: 1.92 min - Logs: {'loss': 1.0445, 'grad_norm': 72.28636932373047, 'learning_rate': 3.467710029064098e-05, 'epoch': 0.1779811848461734}
# ⏱️ Step 800 - Elapsed: 2.18 min - Logs: {'loss': 1.1973, 'grad_norm': 26.247337341308594, 'learning_rate': 3.419325627933024e-05, 'epoch': 0.20340706839562675}
# ⏱️ Step 900 - Elapsed: 2.45 min - Logs: {'loss': 1.0531, 'grad_norm': 0.6968388557434082, 'learning_rate': 3.370941226801949e-05, 'epoch': 0.2288329519450801}
# ⏱️ Step 1000 - Elapsed: 2.71 min - Logs: {'loss': 0.9949, 'grad_norm': 0.6910954713821411, 'learning_rate': 3.322556825670875e-05, 'epoch': 0.25425883549453343}
# ⏱️ Step 1100 - Elapsed: 2.98 min - Logs: {'loss': 1.0243, 'grad_norm': 10.506414413452148, 'learning_rate': 3.2741724245398006e-05, 'epoch': 0.2796847190439868}
# ⏱️ Step 1200 - Elapsed: 3.24 min - Logs: {'loss': 0.9408, 'grad_norm': 0.8316563367843628, 'learning_rate': 3.225788023408726e-05, 'epoch': 0.30511060259344014}
# ⏱️ Step 1300 - Elapsed: 3.51 min - Logs: {'loss': 1.044, 'grad_norm': 133.80104064941406, 'learning_rate': 3.177403622277652e-05, 'epoch': 0.3305364861428935}
# ⏱️ Step 1400 - Elapsed: 3.79 min - Logs: {'loss': 0.9879, 'grad_norm': 13.957005500793457, 'learning_rate': 3.129019221146578e-05, 'epoch': 0.3559623696923468}
# ⏱️ Step 1500 - Elapsed: 4.1 min - Logs: {'loss': 1.0642, 'grad_norm': 47.50313949584961, 'learning_rate': 3.080634820015503e-05, 'epoch': 0.38138825324180015}
# ⏱️ Step 1600 - Elapsed: 4.36 min - Logs: {'loss': 0.9938, 'grad_norm': 0.3818068206310272, 'learning_rate': 3.0322504188844292e-05, 'epoch': 0.4068141367912535}
# ⏱️ Step 1700 - Elapsed: 4.63 min - Logs: {'loss': 0.9368, 'grad_norm': 0.49906715750694275, 'learning_rate': 2.9838660177533545e-05, 'epoch': 0.43224002034070685}
# ⏱️ Step 1800 - Elapsed: 4.89 min - Logs: {'loss': 1.0309, 'grad_norm': 85.67118072509766, 'learning_rate': 2.9354816166222802e-05, 'epoch': 0.4576659038901602}
# ⏱️ Step 1900 - Elapsed: 5.17 min - Logs: {'loss': 0.938, 'grad_norm': 0.34905609488487244, 'learning_rate': 2.887097215491206e-05, 'epoch': 0.4830917874396135}
# ⏱️ Step 2000 - Elapsed: 5.43 min - Logs: {'loss': 0.996, 'grad_norm': 121.79930877685547, 'learning_rate': 2.8387128143601315e-05, 'epoch': 0.5085176709890669}
# ⏱️ Step 2100 - Elapsed: 5.69 min - Logs: {'loss': 0.9301, 'grad_norm': 22.573863983154297, 'learning_rate': 2.7903284132290572e-05, 'epoch': 0.5339435545385202}
# ⏱️ Step 2200 - Elapsed: 5.95 min - Logs: {'loss': 0.8702, 'grad_norm': 7.775796413421631, 'learning_rate': 2.741944012097983e-05, 'epoch': 0.5593694380879736}
# ⏱️ Step 2300 - Elapsed: 6.21 min - Logs: {'loss': 1.1333, 'grad_norm': 0.8424538373947144, 'learning_rate': 2.693559610966909e-05, 'epoch': 0.5847953216374269}
# ⏱️ Step 2400 - Elapsed: 6.47 min - Logs: {'loss': 0.7126, 'grad_norm': 77.45148468017578, 'learning_rate': 2.6451752098358342e-05, 'epoch': 0.6102212051868803}
# ⏱️ Step 2500 - Elapsed: 6.73 min - Logs: {'loss': 0.9215, 'grad_norm': 0.3092249929904938, 'learning_rate': 2.59679080870476e-05, 'epoch': 0.6356470887363336}
# ⏱️ Step 2600 - Elapsed: 6.99 min - Logs: {'loss': 0.9438, 'grad_norm': 35.81794357299805, 'learning_rate': 2.548406407573686e-05, 'epoch': 0.661072972285787}
# ⏱️ Step 2700 - Elapsed: 7.25 min - Logs: {'loss': 0.8728, 'grad_norm': 19.001686096191406, 'learning_rate': 2.500022006442611e-05, 'epoch': 0.6864988558352403}
# ⏱️ Step 2800 - Elapsed: 7.52 min - Logs: {'loss': 1.0748, 'grad_norm': 5.658850193023682, 'learning_rate': 2.4516376053115368e-05, 'epoch': 0.7119247393846936}
# ⏱️ Step 2900 - Elapsed: 7.78 min - Logs: {'loss': 0.9122, 'grad_norm': 0.22025074064731598, 'learning_rate': 2.403253204180462e-05, 'epoch': 0.737350622934147}
# ⏱️ Step 3000 - Elapsed: 8.04 min - Logs: {'loss': 0.9084, 'grad_norm': 13.105539321899414, 'learning_rate': 2.354868803049388e-05, 'epoch': 0.7627765064836003}
# ⏱️ Step 3100 - Elapsed: 8.3 min - Logs: {'loss': 0.8344, 'grad_norm': 0.12610948085784912, 'learning_rate': 2.3064844019183138e-05, 'epoch': 0.7882023900330537}
# ⏱️ Step 3200 - Elapsed: 8.59 min - Logs: {'loss': 0.9222, 'grad_norm': 94.26427459716797, 'learning_rate': 2.2581000007872395e-05, 'epoch': 0.813628273582507}
# ⏱️ Step 3300 - Elapsed: 8.85 min - Logs: {'loss': 0.9371, 'grad_norm': 16.823001861572266, 'learning_rate': 2.209715599656165e-05, 'epoch': 0.8390541571319603}
# ⏱️ Step 3400 - Elapsed: 9.11 min - Logs: {'loss': 0.9723, 'grad_norm': 158.06048583984375, 'learning_rate': 2.1613311985250908e-05, 'epoch': 0.8644800406814137}
# ⏱️ Step 3500 - Elapsed: 9.37 min - Logs: {'loss': 0.6689, 'grad_norm': 0.40354377031326294, 'learning_rate': 2.1129467973940165e-05, 'epoch': 0.889905924230867}
# ⏱️ Step 3600 - Elapsed: 9.63 min - Logs: {'loss': 1.0209, 'grad_norm': 17.131696701049805, 'learning_rate': 2.0645623962629425e-05, 'epoch': 0.9153318077803204}
# ⏱️ Step 3700 - Elapsed: 9.89 min - Logs: {'loss': 0.8555, 'grad_norm': 0.37425369024276733, 'learning_rate': 2.0161779951318678e-05, 'epoch': 0.9407576913297737}
# ⏱️ Step 3800 - Elapsed: 10.15 min - Logs: {'loss': 1.0034, 'grad_norm': 0.6714603304862976, 'learning_rate': 1.9677935940007935e-05, 'epoch': 0.966183574879227}
# ⏱️ Step 3900 - Elapsed: 10.41 min - Logs: {'loss': 1.0217, 'grad_norm': 14.452984809875488, 'learning_rate': 1.9194091928697188e-05, 'epoch': 0.9916094584286804}
# ⏱️ Step 3933 - Elapsed: 10.79 min - Logs: {'eval_loss': 0.8831360340118408, 'eval_f1': 0.8024503414637258, 'eval_runtime': 17.7096, 'eval_samples_per_second': 55.563, 'eval_steps_per_second': 6.945, 'epoch': 1.0}
# ⏱️ Step 4000 - Elapsed: 10.99 min - Logs: {'loss': 0.716, 'grad_norm': 0.22775135934352875, 'learning_rate': 1.8710247917386448e-05, 'epoch': 1.0170353419781337}
# ⏱️ Step 4100 - Elapsed: 11.26 min - Logs: {'loss': 0.7241, 'grad_norm': 0.11235237121582031, 'learning_rate': 1.8226403906075704e-05, 'epoch': 1.0424612255275871}
# ⏱️ Step 4200 - Elapsed: 11.52 min - Logs: {'loss': 0.7496, 'grad_norm': 88.73048400878906, 'learning_rate': 1.774255989476496e-05, 'epoch': 1.0678871090770405}
# ⏱️ Step 4300 - Elapsed: 11.78 min - Logs: {'loss': 0.7725, 'grad_norm': 0.16396670043468475, 'learning_rate': 1.7258715883454218e-05, 'epoch': 1.0933129926264937}
# ⏱️ Step 4400 - Elapsed: 12.04 min - Logs: {'loss': 0.5302, 'grad_norm': 0.4975303113460541, 'learning_rate': 1.6774871872143474e-05, 'epoch': 1.1187388761759471}
# ⏱️ Step 4500 - Elapsed: 12.31 min - Logs: {'loss': 0.9178, 'grad_norm': 17.79718780517578, 'learning_rate': 1.629102786083273e-05, 'epoch': 1.1441647597254005}
# ⏱️ Step 4600 - Elapsed: 12.57 min - Logs: {'loss': 0.802, 'grad_norm': 24.821014404296875, 'learning_rate': 1.5807183849521988e-05, 'epoch': 1.1695906432748537}
# ⏱️ Step 4700 - Elapsed: 12.83 min - Logs: {'loss': 0.7885, 'grad_norm': 0.10756160318851471, 'learning_rate': 1.5323339838211244e-05, 'epoch': 1.1950165268243071}
# ⏱️ Step 4800 - Elapsed: 13.11 min - Logs: {'loss': 0.6617, 'grad_norm': 0.0685587152838707, 'learning_rate': 1.48394958269005e-05, 'epoch': 1.2204424103737606}
# ⏱️ Step 4900 - Elapsed: 13.4 min - Logs: {'loss': 0.5896, 'grad_norm': 0.15843892097473145, 'learning_rate': 1.4355651815589758e-05, 'epoch': 1.2458682939232137}
# ⏱️ Step 5000 - Elapsed: 13.66 min - Logs: {'loss': 0.8906, 'grad_norm': 0.1403784453868866, 'learning_rate': 1.3871807804279012e-05, 'epoch': 1.2712941774726672}
# ⏱️ Step 5100 - Elapsed: 13.92 min - Logs: {'loss': 0.7794, 'grad_norm': 17.40302276611328, 'learning_rate': 1.338796379296827e-05, 'epoch': 1.2967200610221206}
# ⏱️ Step 5200 - Elapsed: 14.18 min - Logs: {'loss': 0.7065, 'grad_norm': 0.1291145533323288, 'learning_rate': 1.2904119781657527e-05, 'epoch': 1.3221459445715738}
# ⏱️ Step 5300 - Elapsed: 14.45 min - Logs: {'loss': 0.5204, 'grad_norm': 0.15606239438056946, 'learning_rate': 1.2420275770346782e-05, 'epoch': 1.3475718281210272}
# ⏱️ Step 5400 - Elapsed: 14.71 min - Logs: {'loss': 0.7012, 'grad_norm': 0.10328970849514008, 'learning_rate': 1.193643175903604e-05, 'epoch': 1.3729977116704806}
# ⏱️ Step 5500 - Elapsed: 14.97 min - Logs: {'loss': 0.6763, 'grad_norm': 0.6401452422142029, 'learning_rate': 1.1452587747725296e-05, 'epoch': 1.398423595219934}
# ⏱️ Step 5600 - Elapsed: 15.23 min - Logs: {'loss': 0.7117, 'grad_norm': 0.260903537273407, 'learning_rate': 1.0968743736414552e-05, 'epoch': 1.4238494787693872}
# ⏱️ Step 5700 - Elapsed: 15.5 min - Logs: {'loss': 0.6673, 'grad_norm': 75.40280151367188, 'learning_rate': 1.048489972510381e-05, 'epoch': 1.4492753623188406}
# ⏱️ Step 5800 - Elapsed: 15.77 min - Logs: {'loss': 0.6564, 'grad_norm': 0.4578910768032074, 'learning_rate': 1.0001055713793066e-05, 'epoch': 1.474701245868294}
# ⏱️ Step 5900 - Elapsed: 16.03 min - Logs: {'loss': 0.4294, 'grad_norm': 0.07458759844303131, 'learning_rate': 9.517211702482324e-06, 'epoch': 1.5001271294177472}
# ⏱️ Step 6000 - Elapsed: 16.29 min - Logs: {'loss': 0.8038, 'grad_norm': 242.3209686279297, 'learning_rate': 9.033367691171579e-06, 'epoch': 1.5255530129672006}
# ⏱️ Step 6100 - Elapsed: 16.55 min - Logs: {'loss': 0.6175, 'grad_norm': 0.27740395069122314, 'learning_rate': 8.549523679860835e-06, 'epoch': 1.550978896516654}
# ⏱️ Step 6200 - Elapsed: 16.81 min - Logs: {'loss': 0.5202, 'grad_norm': 17.888093948364258, 'learning_rate': 8.065679668550092e-06, 'epoch': 1.5764047800661074}
# ⏱️ Step 6300 - Elapsed: 17.08 min - Logs: {'loss': 0.9343, 'grad_norm': 44.097049713134766, 'learning_rate': 7.581835657239349e-06, 'epoch': 1.6018306636155606}
# ⏱️ Step 6400 - Elapsed: 17.34 min - Logs: {'loss': 0.8471, 'grad_norm': 19.947500228881836, 'learning_rate': 7.097991645928606e-06, 'epoch': 1.627256547165014}
# ⏱️ Step 6500 - Elapsed: 17.6 min - Logs: {'loss': 0.5078, 'grad_norm': 0.2389097809791565, 'learning_rate': 6.614147634617863e-06, 'epoch': 1.6526824307144672}
# ⏱️ Step 6600 - Elapsed: 17.86 min - Logs: {'loss': 0.9634, 'grad_norm': 381.7322692871094, 'learning_rate': 6.130303623307119e-06, 'epoch': 1.6781083142639206}
# ⏱️ Step 6700 - Elapsed: 18.12 min - Logs: {'loss': 0.4863, 'grad_norm': 200.7095947265625, 'learning_rate': 5.646459611996375e-06, 'epoch': 1.703534197813374}
# ⏱️ Step 6800 - Elapsed: 18.38 min - Logs: {'loss': 0.6233, 'grad_norm': 0.19262520968914032, 'learning_rate': 5.162615600685632e-06, 'epoch': 1.7289600813628274}
# ⏱️ Step 6900 - Elapsed: 18.64 min - Logs: {'loss': 0.4923, 'grad_norm': 10.09807300567627, 'learning_rate': 4.6787715893748885e-06, 'epoch': 1.7543859649122808}
# ⏱️ Step 7000 - Elapsed: 18.9 min - Logs: {'loss': 0.5544, 'grad_norm': 0.09796440601348877, 'learning_rate': 4.194927578064146e-06, 'epoch': 1.779811848461734}
# ⏱️ Step 7100 - Elapsed: 19.16 min - Logs: {'loss': 0.6558, 'grad_norm': 0.16133470833301544, 'learning_rate': 3.711083566753402e-06, 'epoch': 1.8052377320111874}
# ⏱️ Step 7200 - Elapsed: 19.42 min - Logs: {'loss': 0.7086, 'grad_norm': 0.14279022812843323, 'learning_rate': 3.2272395554426584e-06, 'epoch': 1.8306636155606406}
# ⏱️ Step 7300 - Elapsed: 19.68 min - Logs: {'loss': 0.5806, 'grad_norm': 0.1552981436252594, 'learning_rate': 2.7433955441319154e-06, 'epoch': 1.856089499110094}
# ⏱️ Step 7400 - Elapsed: 19.94 min - Logs: {'loss': 0.4698, 'grad_norm': 0.09538276493549347, 'learning_rate': 2.2595515328211716e-06, 'epoch': 1.8815153826595474}
# ⏱️ Step 7500 - Elapsed: 20.2 min - Logs: {'loss': 0.5986, 'grad_norm': 0.07538342475891113, 'learning_rate': 1.7757075215104283e-06, 'epoch': 1.9069412662090008}
# ⏱️ Step 7600 - Elapsed: 20.47 min - Logs: {'loss': 0.7365, 'grad_norm': 60.22339630126953, 'learning_rate': 1.291863510199685e-06, 'epoch': 1.9323671497584543}
# ⏱️ Step 7700 - Elapsed: 20.73 min - Logs: {'loss': 0.7281, 'grad_norm': 286.66827392578125, 'learning_rate': 8.080194988889415e-07, 'epoch': 1.9577930333079074}
# ⏱️ Step 7800 - Elapsed: 20.99 min - Logs: {'loss': 0.7894, 'grad_norm': 0.17683079838752747, 'learning_rate': 3.2417548757819805e-07, 'epoch': 1.9832189168573608}
# ⏱️ Step 7866 - Elapsed: 21.46 min - Logs: {'eval_loss': 0.7439549565315247, 'eval_f1': 0.8566600732687818, 'eval_runtime': 17.7135, 'eval_samples_per_second': 55.551, 'eval_steps_per_second': 6.944, 'epoch': 2.0}
# ⏱️ Step 7866 - Elapsed: 21.49 min - Logs: {'train_runtime': 1289.4011, 'train_samples_per_second': 12.201, 'train_steps_per_second': 6.101, 'total_flos': 2084014280429568.0, 'train_loss': 0.8263965090691755, 'epoch': 2.0}
# [I 2025-05-29 16:42:04,485] Trial 1 finished with value: 0.8566600732687818 and parameters: {'learning_rate': 3.8059169929703077e-05, 'per_device_train_batch_size': 2, 'num_train_epochs': 2}. Best is trial 1 with value: 0.8566600732687818.
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting trial at 16:42:05
#     <div>
#
#       <progress value='3934' max='3934' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3934/3934 16:53, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.689200</td>
#       <td>0.597391</td>
#       <td>0.830417</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.479200</td>
#       <td>0.591610</td>
#       <td>0.876295</td>
#     </tr>
#   </tbody>
# </table><p>
# ⏱️ Step 100 - Elapsed: 0.42 min - Logs: {'loss': 1.0015, 'grad_norm': 3.291795253753662, 'learning_rate': 5.689421646063128e-05, 'epoch': 0.05083884087442806}
# ⏱️ Step 200 - Elapsed: 0.84 min - Logs: {'loss': 0.6669, 'grad_norm': 16.933544158935547, 'learning_rate': 5.541066453206202e-05, 'epoch': 0.10167768174885612}
# ⏱️ Step 300 - Elapsed: 1.26 min - Logs: {'loss': 0.7886, 'grad_norm': 8.993491172790527, 'learning_rate': 5.3927112603492754e-05, 'epoch': 0.1525165226232842}
# ⏱️ Step 400 - Elapsed: 1.67 min - Logs: {'loss': 0.8002, 'grad_norm': 46.60826873779297, 'learning_rate': 5.2443560674923494e-05, 'epoch': 0.20335536349771224}
# ⏱️ Step 500 - Elapsed: 2.09 min - Logs: {'loss': 0.7106, 'grad_norm': 14.087248802185059, 'learning_rate': 5.096000874635423e-05, 'epoch': 0.2541942043721403}
# ⏱️ Step 600 - Elapsed: 2.5 min - Logs: {'loss': 0.713, 'grad_norm': 8.977178573608398, 'learning_rate': 4.947645681778496e-05, 'epoch': 0.3050330452465684}
# ⏱️ Step 700 - Elapsed: 2.92 min - Logs: {'loss': 0.677, 'grad_norm': 10.93317699432373, 'learning_rate': 4.79929048892157e-05, 'epoch': 0.35587188612099646}
# ⏱️ Step 800 - Elapsed: 3.33 min - Logs: {'loss': 0.7372, 'grad_norm': 1.082209825515747, 'learning_rate': 4.650935296064643e-05, 'epoch': 0.4067107269954245}
# ⏱️ Step 900 - Elapsed: 3.75 min - Logs: {'loss': 0.6746, 'grad_norm': 4.58318567276001, 'learning_rate': 4.502580103207717e-05, 'epoch': 0.45754956786985257}
# ⏱️ Step 1000 - Elapsed: 4.18 min - Logs: {'loss': 0.7144, 'grad_norm': 27.91490936279297, 'learning_rate': 4.3542249103507906e-05, 'epoch': 0.5083884087442806}
# ⏱️ Step 1100 - Elapsed: 4.61 min - Logs: {'loss': 0.6448, 'grad_norm': 42.44123077392578, 'learning_rate': 4.205869717493864e-05, 'epoch': 0.5592272496187087}
# ⏱️ Step 1200 - Elapsed: 5.04 min - Logs: {'loss': 0.6502, 'grad_norm': 39.77409362792969, 'learning_rate': 4.057514524636937e-05, 'epoch': 0.6100660904931368}
# ⏱️ Step 1300 - Elapsed: 5.46 min - Logs: {'loss': 0.7731, 'grad_norm': 21.851242065429688, 'learning_rate': 3.909159331780011e-05, 'epoch': 0.6609049313675648}
# ⏱️ Step 1400 - Elapsed: 5.89 min - Logs: {'loss': 0.6136, 'grad_norm': 19.863893508911133, 'learning_rate': 3.760804138923085e-05, 'epoch': 0.7117437722419929}
# ⏱️ Step 1500 - Elapsed: 6.32 min - Logs: {'loss': 0.6726, 'grad_norm': 17.569406509399414, 'learning_rate': 3.6124489460661585e-05, 'epoch': 0.762582613116421}
# ⏱️ Step 1600 - Elapsed: 6.73 min - Logs: {'loss': 0.6529, 'grad_norm': 16.199995040893555, 'learning_rate': 3.4640937532092325e-05, 'epoch': 0.813421453990849}
# ⏱️ Step 1700 - Elapsed: 7.14 min - Logs: {'loss': 0.8364, 'grad_norm': 15.40487289428711, 'learning_rate': 3.315738560352305e-05, 'epoch': 0.8642602948652771}
# ⏱️ Step 1800 - Elapsed: 7.55 min - Logs: {'loss': 0.6746, 'grad_norm': 4.722644329071045, 'learning_rate': 3.167383367495379e-05, 'epoch': 0.9150991357397051}
# ⏱️ Step 1900 - Elapsed: 7.96 min - Logs: {'loss': 0.6892, 'grad_norm': 25.675928115844727, 'learning_rate': 3.0190281746384528e-05, 'epoch': 0.9659379766141332}
# ⏱️ Step 1967 - Elapsed: 8.52 min - Logs: {'eval_loss': 0.5973906517028809, 'eval_f1': 0.8304172160193616, 'eval_runtime': 17.1842, 'eval_samples_per_second': 57.262, 'eval_steps_per_second': 7.158, 'epoch': 1.0}
# ⏱️ Step 2000 - Elapsed: 8.69 min - Logs: {'loss': 0.6642, 'grad_norm': 17.501771926879883, 'learning_rate': 2.8706729817815264e-05, 'epoch': 1.0167768174885612}
# ⏱️ Step 2100 - Elapsed: 9.1 min - Logs: {'loss': 0.5657, 'grad_norm': 74.2796401977539, 'learning_rate': 2.7223177889245997e-05, 'epoch': 1.0676156583629894}
# ⏱️ Step 2200 - Elapsed: 9.5 min - Logs: {'loss': 0.4786, 'grad_norm': 0.379434198141098, 'learning_rate': 2.5739625960676734e-05, 'epoch': 1.1184544992374175}
# ⏱️ Step 2300 - Elapsed: 9.91 min - Logs: {'loss': 0.6225, 'grad_norm': 0.20817561447620392, 'learning_rate': 2.425607403210747e-05, 'epoch': 1.1692933401118455}
# ⏱️ Step 2400 - Elapsed: 10.32 min - Logs: {'loss': 0.5907, 'grad_norm': 9.565454483032227, 'learning_rate': 2.2772522103538203e-05, 'epoch': 1.2201321809862735}
# ⏱️ Step 2500 - Elapsed: 10.73 min - Logs: {'loss': 0.5507, 'grad_norm': 13.913836479187012, 'learning_rate': 2.128897017496894e-05, 'epoch': 1.2709710218607015}
# ⏱️ Step 2600 - Elapsed: 11.14 min - Logs: {'loss': 0.6559, 'grad_norm': 1.1372100114822388, 'learning_rate': 1.980541824639968e-05, 'epoch': 1.3218098627351296}
# ⏱️ Step 2700 - Elapsed: 11.55 min - Logs: {'loss': 0.4501, 'grad_norm': 1.2904642820358276, 'learning_rate': 1.8321866317830413e-05, 'epoch': 1.3726487036095576}
# ⏱️ Step 2800 - Elapsed: 11.95 min - Logs: {'loss': 0.5466, 'grad_norm': 83.02423858642578, 'learning_rate': 1.683831438926115e-05, 'epoch': 1.4234875444839858}
# ⏱️ Step 2900 - Elapsed: 12.36 min - Logs: {'loss': 0.4464, 'grad_norm': 1.0386945009231567, 'learning_rate': 1.5354762460691886e-05, 'epoch': 1.4743263853584139}
# ⏱️ Step 3000 - Elapsed: 12.77 min - Logs: {'loss': 0.5517, 'grad_norm': 0.1625615507364273, 'learning_rate': 1.387121053212262e-05, 'epoch': 1.525165226232842}
# ⏱️ Step 3100 - Elapsed: 13.18 min - Logs: {'loss': 0.4816, 'grad_norm': 0.4150433838367462, 'learning_rate': 1.2387658603553355e-05, 'epoch': 1.57600406710727}
# ⏱️ Step 3200 - Elapsed: 13.58 min - Logs: {'loss': 0.6873, 'grad_norm': 67.1366958618164, 'learning_rate': 1.0904106674984092e-05, 'epoch': 1.6268429079816982}
# ⏱️ Step 3300 - Elapsed: 13.99 min - Logs: {'loss': 0.5852, 'grad_norm': 69.38565063476562, 'learning_rate': 9.420554746414828e-06, 'epoch': 1.6776817488561262}
# ⏱️ Step 3400 - Elapsed: 14.4 min - Logs: {'loss': 0.4734, 'grad_norm': 43.74059295654297, 'learning_rate': 7.937002817845563e-06, 'epoch': 1.7285205897305542}
# ⏱️ Step 3500 - Elapsed: 14.8 min - Logs: {'loss': 0.3722, 'grad_norm': 185.10723876953125, 'learning_rate': 6.453450889276299e-06, 'epoch': 1.7793594306049823}
# ⏱️ Step 3600 - Elapsed: 15.21 min - Logs: {'loss': 0.6031, 'grad_norm': 38.51866912841797, 'learning_rate': 4.9698989607070354e-06, 'epoch': 1.8301982714794103}
# ⏱️ Step 3700 - Elapsed: 15.62 min - Logs: {'loss': 0.4336, 'grad_norm': 6.0497660636901855, 'learning_rate': 3.4863470321377707e-06, 'epoch': 1.8810371123538383}
# ⏱️ Step 3800 - Elapsed: 16.02 min - Logs: {'loss': 0.4748, 'grad_norm': 78.0797348022461, 'learning_rate': 2.0027951035685067e-06, 'epoch': 1.9318759532282663}
# ⏱️ Step 3900 - Elapsed: 16.43 min - Logs: {'loss': 0.4792, 'grad_norm': 0.1556871086359024, 'learning_rate': 5.192431749992425e-07, 'epoch': 1.9827147941026944}
# ⏱️ Step 3934 - Elapsed: 16.86 min - Logs: {'eval_loss': 0.5916100740432739, 'eval_f1': 0.8762950743602529, 'eval_runtime': 17.3638, 'eval_samples_per_second': 56.67, 'eval_steps_per_second': 7.084, 'epoch': 2.0}
# ⏱️ Step 3934 - Elapsed: 16.89 min - Logs: {'train_runtime': 1013.4575, 'train_samples_per_second': 15.523, 'train_steps_per_second': 3.882, 'total_flos': 2084014280429568.0, 'train_loss': 0.6230564156218598, 'epoch': 2.0}
# [I 2025-05-29 16:58:59,031] Trial 2 finished with value: 0.8762950743602529 and parameters: {'learning_rate': 5.8362932869914855e-05, 'per_device_train_batch_size': 4, 'num_train_epochs': 2}. Best is trial 2 with value: 0.8762950743602529.
# ✅ Done!
# ⏱️ Optuna tuning done in 72.95 minutes
# 🏆 Best trial params: {'learning_rate': 5.8362932869914855e-05, 'per_device_train_batch_size': 4, 'num_train_epochs': 2}

# %% [markdown]
# ### Saving the best parameters

# %%
print("🏆 Best trial F1 score:", best_trial.objective)
print("📋 Best trial hyperparameters:", best_trial.hyperparameters)
# Out:
# 🏆 Best trial F1 score: 0.8762950743602529
# 📋 Best trial hyperparameters: {'learning_rate': 5.8362932869914855e-05, 'per_device_train_batch_size': 4, 'num_train_epochs': 2}

# %%
import json
# Save best params
with open("best_params_DistilRB.json", "w") as f:
    json.dump(best_trial.hyperparameters, f)

print("✅ Best hyperparameters saved.")
# Out:
# ✅ Best hyperparameters saved.

# %% [markdown]
# ### Final model

# %% [markdown]
# #### Merging Train and Validation Sets
#
# The training and validation datasets are merged into a single full training set.
# This allows the final model to be trained using all available labeled data for better performance, instead of wasting examples on separate validation.

# %%
# Merge train and validation splits
full_train_dataset = Dataset.from_dict({
    key: tokenized_dataset["train"][key] + tokenized_dataset["validation"][key]
    for key in tokenized_dataset["train"].features
})

# %% [markdown]
# ### Final version

# %% [markdown]
# In this final version, the model is fine-tuned using the best hyperparameters previously found with Optuna.
#
# Class imbalance is addressed by assigning a higher weight to the Neutral class during training.
#
# A custom WeightedTrainer is used to apply class weights correctly through a modified loss function (CrossEntropyLoss).
#
# Training is done on the full training dataset, with no evaluation during training (evaluation_strategy="no"), to prevent data leakage.
#
# After training, predictions are made on the separate test set, and a threshold optimization is applied to better distinguish Neutral class predictions.
#
# Finally, classification metrics, a confusion matrix, and the weighted F1-score are printed to summarize the model's performance.

# %%
#  Imports
import torch
import json
import numpy as np
import time
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from torch import nn

#  Load Best Parameters
with open("best_params_DistilRB.json", "r") as f:
    best_params = json.load(f)



#  Class weights
class_weights = torch.tensor([1.0, 1.0, 2.0], dtype=torch.float).to("cuda")  # Neutral weighted higher


#  Custom Trainer to inject class weights
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")
        loss_fct = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits, labels)
        return (loss, outputs) if return_outputs else loss

#  Model Init function
def model_init():
    model = AutoModelForSequenceClassification.from_pretrained(
        model_id,
        num_labels=3
    )
    model.config.pad_token_id = tokenizer.pad_token_id
    return model


#  Training Args
final_training_args = TrainingArguments(
    output_dir="./final",
    eval_strategy="no",
    save_strategy="no",  
    learning_rate=best_params["learning_rate"],
    per_device_train_batch_size=best_params["per_device_train_batch_size"],
    num_train_epochs=3,
    report_to="none",
    fp16=False
)

#  Final Trainer
final_trainer = WeightedTrainer(
    model_init=model_init,
    args=final_training_args,
    train_dataset=full_train_dataset,  # <<< Full train
    tokenizer=tokenizer
)

#  Train
start = time.time()
final_trainer.train()
end = time.time()
print(f"\n✅ Final training completed in {round((end-start)/60, 2)} minutes.")

#  Save Model
final_trainer.save_model("finalBALANCE")
print(" Final model saved to 'finalBALANCE' folder.")

#  Predictions
predictions = final_trainer.predict(tokenized_dataset["test"])
probs = torch.softmax(torch.tensor(predictions.predictions), dim=1).numpy()
labels = predictions.label_ids

#  Auto Threshold Optimization
from scipy.optimize import minimize_scalar

def threshold_objective(thresh):
    preds = np.argmax(probs, axis=1)
    max_probs = np.max(probs, axis=1)
    preds[max_probs < thresh] = 2  # Force to Neutral if uncertain
    return -f1_score(labels, preds, average="weighted")

opt_result = minimize_scalar(threshold_objective, bounds=(0.3, 0.7), method="bounded")
best_thresh = opt_result.x
print(f"\n🔍 Best Neutral Threshold found: {round(best_thresh, 3)}")

#  Apply Best Threshold
preds = np.argmax(probs, axis=1)
max_probs = np.max(probs, axis=1)
preds[max_probs < best_thresh] = 2  # Again force Neutral

#  Print Metrics
print("\n📘 Classification Report (Final):")
print(classification_report(labels, preds, target_names=['Negative', 'Positive', 'Neutral']))

print("\n✅ Confusion Matrix:")
print(confusion_matrix(labels, preds))

final_f1 = f1_score(labels, preds, average="weighted")
print(f"\n🔴 Final Weighted F1 (with threshold): {round(final_f1, 4)}")
# Out:
# C:\Users\Alicia\AppData\Local\Temp\ipykernel_792\1441673826.py:54: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedTrainer.__init__`. Use `processing_class` instead.
#   final_trainer = WeightedTrainer(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='6639' max='6639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6639/6639 28:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.800400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.756200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.703300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.716600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.639000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.611900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.627000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.570600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.516200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.417800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.463500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.401500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.366900</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Final training completed in 28.06 minutes.
#  Final model saved to 'finalBALANCE' folder.
# 🔍 Best Neutral Threshold found: 0.394
#
# 📘 Classification Report (Final):
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.89      0.85       302
#     Positive       0.87      0.90      0.88       341
#      Neutral       0.53      0.38      0.44       167
#
#     accuracy                           0.79       810
#    macro avg       0.73      0.72      0.72       810
# weighted avg       0.77      0.79      0.78       810
#
#
# ✅ Confusion Matrix:
# [[270   2  30]
#  [  8 306  27]
#  [ 59  44  64]]
#
# 🔴 Final Weighted F1 (with threshold): 0.7785

# %%
import torch
import torch.nn.functional as F
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from scipy.optimize import minimize_scalar

# === Predict on test set ===
predictions = final_trainer.predict(tokenized_dataset["test"])
logits = predictions.predictions
labels = predictions.label_ids

# === Apply softmax with temperature scaling ===
temperature = 2 
probs = F.softmax(torch.tensor(logits / temperature), dim=-1).numpy()

# === Define threshold optimization using confidence margin ===
def threshold_objective(margin):
    final_preds = []
    for p in probs:
        top2 = np.sort(p)[-2:]        # take two highest probs
        gap = top2[1] - top2[0]       # confidence gap
        if gap < margin:
            final_preds.append(2)     # force Neutral
        else:
            final_preds.append(np.argmax(p))
    return -f1_score(labels, final_preds, average="weighted")

# === Find best neutral margin ===
opt_result = minimize_scalar(threshold_objective, bounds=(0.05, 0.4), method="bounded")
neutral_margin = opt_result.x
print(f"\n🔍 Best Neutral Confidence Margin found: {round(neutral_margin, 3)}")

# === Apply margin to get final predictions ===
final_preds = []
for p in probs:
    top2 = np.sort(p)[-2:]
    gap = top2[1] - top2[0]
    if gap < neutral_margin:
        final_preds.append(2)
    else:
        final_preds.append(np.argmax(p))

# === Evaluation ===
print("\n📘 Classification Report (Confidence + Temperature):")
print(classification_report(labels, final_preds, target_names=["Negative", "Positive", "Neutral"]))

print("\n✅ Confusion Matrix:")
print(confusion_matrix(labels, final_preds))

final_f1 = f1_score(labels, final_preds, average="weighted")
print(f"\n🔴 Final Weighted F1 (with threshold): {round(final_f1, 4)}")
# Out:
# 🔍 Best Neutral Confidence Margin found: 0.121
#
# 📘 Classification Report (Confidence + Temperature):
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.89      0.84       302
#     Positive       0.87      0.89      0.88       341
#      Neutral       0.52      0.40      0.45       167
#
#     accuracy                           0.79       810
#    macro avg       0.73      0.73      0.73       810
# weighted avg       0.77      0.79      0.78       810
#
#
# ✅ Confusion Matrix:
# [[268   2  32]
#  [  8 305  28]
#  [ 58  43  66]]
#
# 🔴 Final Weighted F1 (with threshold): 0.7787

# %%
from sklearn.metrics import accuracy_score

final_accuracy = accuracy_score(labels, preds)

print(f"\n✅ Final Accuracy: {final_accuracy:.4f}")
print(f"✅ Final Weighted F1-score: {final_f1:.4f}")
# Out:
# ✅ Final Accuracy: 0.7901
# ✅ Final Weighted F1-score: 0.7787
